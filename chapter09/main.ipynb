# %% [markdown]
# <h1>Chapter10 "FAST"主动反射面的形状调节<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# # 1. 预先检查
# - <font color=white size=4 face=雅黑>读者可以通过以下代码检查所需要的库是否已经正确安装，若依赖的库未被正确安装，以下代码将会自动安装；</font>
# - <font color=white size=4 face=雅黑>运行后如果依然显示库未被安装，可以尝试关闭代码窗口后重新打开；</font>

# %%
# !pip install tqdm
# !pip install pandas
# !pip install matplotlib
# !pip install numpy
# !pip install jax
# !pip install jaxlib
# Out:
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple
# Requirement already satisfied: tqdm in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (4.62.3)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/home/andy/anaconda3/envs/jax_book/bin/python -m pip install --upgrade pip' command.
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple
# Requirement already satisfied: pandas in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (1.3.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from pandas) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/home/andy/anaconda3/envs/jax_book/bin/python -m pip install --upgrade pip' command.
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple
# Requirement already satisfied: matplotlib in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (3.4.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from matplotlib) (8.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.16 in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: cycler>=0.10 in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: six in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/home/andy/anaconda3/envs/jax_book/bin/python -m pip install --upgrade pip' command.
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple
# Requirement already satisfied: numpy in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (1.20.3)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/home/andy/anaconda3/envs/jax_book/bin/python -m pip install --upgrade pip' command.
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple
# Requirement already satisfied: jax in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (0.2.21)
# Requirement already satisfied: opt-einsum in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from jax) (3.3.0)
# Requirement already satisfied: absl-py in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from jax) (0.14.1)
# Requirement already satisfied: numpy>=1.18 in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from jax) (1.20.3)
# Requirement already satisfied: scipy>=1.2.1 in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from jax) (1.7.1)
# Requirement already satisfied: six in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from absl-py->jax) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/home/andy/anaconda3/envs/jax_book/bin/python -m pip install --upgrade pip' command.
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple
# Requirement already satisfied: jaxlib in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (0.1.71)
# Requirement already satisfied: scipy in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from jaxlib) (1.7.1)
# Requirement already satisfied: numpy>=1.18 in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from jaxlib) (1.20.3)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from jaxlib) (2.0)
# Requirement already satisfied: absl-py in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from jaxlib) (0.14.1)
# Requirement already satisfied: six in /home/andy/anaconda3/envs/jax_book/lib/python3.9/site-packages (from absl-py->jaxlib) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/home/andy/anaconda3/envs/jax_book/bin/python -m pip install --upgrade pip' command.

# %%
import jax
import jax.numpy as jnp
import numpy as np
from jax.config import config

config.update("jax_enable_x64",True)

# %% [markdown]
# # 2. 类的导入

# %% [markdown]
# ## 2.1 类型检查
# - <font color=white size=4 face=雅黑>定义**常数**类 ScalorType, 作为程序输出应该为**常数**时的类型检查；</font>
# - <font color=white size=4 face=雅黑>定义**长度**类 LengthType, 作为程序输出应该为**长度**时的类型检查；</font>

# %%
from typing import Union, List, Optional, Set, Callable

ScalorType = Union[float, np.ndarray, jnp.ndarray]
LengthType = Union[float, np.ndarray, jnp.ndarray]

# %% [markdown]
# ## 2.2 Point类
# - <font color=white size=4 face=雅黑>对应着三维空间之中的一个点，具有坐标 **(x,y,z)**,以及 **name**参数，具体定义如下；</font>
# - <font color=white size=4 face=雅黑>如果两个`Point`类的 **name**相等，那么我们就认为这两个点是同一个点，这里**不会**对坐标是否相等进行另外检查；</font>
# - <font color=white size=4 face=雅黑>如果 **p**是一个`Point`类的实例，则可以通过 **print(p)** 查看该点的信息；</font>

# %%
class Point(object):
    def __init__(self, x: Optional[ScalorType], 
                       y: Optional[ScalorType] = 0., 
                       z: Optional[ScalorType] = 0., 
                       name: str = None):
        self.x = x
        self.y = y
        self.z = z
        self.name = name

    def __eq__(self, other):
        # 如果 P1 和 P2 都是 Point类，且名称（也就是name参数）相同，我们就认为两个点是相同的， 
        #     ———— 也就是说 P1 == P2 将会返回 True
        if type(self) != type(other): return False
        return self.name == other.name
    
    def __str__(self):
        # 指定调用print函数时，程序终端将会输出的string
        return "class Point:\n\t name = {} \n\t position = ({}, {}, {})"\
                .format(self.name, self.x, self.y, self.z)
    
    @property
    def position(self):
        return (self.x, self.y, self.z)

# %% [markdown]
# Point类测试

# %%
Origin = Point(0., 0., 0., name="Origin")
print(Origin)
# Out:
# class Point:
# 	 name = Origin
# 	 position = (0.0, 0.0, 0.0)

# %% [markdown]
# ## 2.3 Vertex类
# - <font color=white size=4 face=雅黑>`Vertex`类继承自`Point`类，但不同的是，`Point`类代表**空间**之中的一个**点**，而`Vertex`类代表的是**图**上的一个**顶点**；相比于其父类`Point`，`Vertex`类增加了近邻节点的信息，用一个列表**self.adjacent**储存图上近邻的顶点(的指针)</font>
# - <font color=white size=4 face=雅黑>如果 **v**是一个`Vertex`类的实例，则可以通过 **print(v)** 查看该点的信息；</font>
# - <font color=white size=4 face=雅黑>如果两个`Vertex`类的 **name**相等，那么我们就认为这两个顶点是同一个点，这里**会对**坐标是否相等进行另外检查；</font>
# - <font color=white size=4 face=雅黑>`VertexInfo`类用于储存有关于`Vertex`的信息，在这里，信息包括：</font>
#
#   - <font color=white size=3.5 face=雅黑>self.idx   : 顶点在主索节点列表之中的位置</font>
#   - <font color=white size=3.5 face=雅黑>self.status: 顶点目前所在的状态</font>
#   - <font color=white size=3.5 face=雅黑>self.vertex_init_pos  : 顶点的初始位置</font>
#   - <font color=white size=3.5 face=雅黑>self.vertex_ground_pos: 顶点对应固定在地面上的促动器的坐标 </font>

# %%
class VertexInfo(object):
    def __init__(self, index:int = -1,
                       status: int = -1,
                       vertex_init_pos  :np.ndarray = None,
                       vertex_ground_pos:np.ndarray = None):
        self.idx: int = index     # 储存该顶点在输入 3xN 顶点列表之中的位置
        self._status: int = status # 描述该节点目前的状态, 0表示位于工作区，1表示位于工作区外（但不固定），2表示该节点固定
        self.vertex_init_pos  : np.ndarray = vertex_init_pos   # 顶点的初始位置
        self.vertex_ground_pos: np.ndarray = vertex_ground_pos # 固定在地面上的促动器的坐标 
    
    @property
    def status(self):
        if self._status == 0: return "working"
        if self._status == 1: return "idling"
        if self._status == 2: return "fixing"
        return "unsure"

# %%
import logging

class Vertex(Point):
    def __init__(self, name: str, 
                          x: ScalorType = None, 
                          y: ScalorType = None, 
                          z: ScalorType = None,
                          info:VertexInfo = None):
        super().__init__(x, y, z, name = name)  # 初始化顶点的名称及位置参数
        self.adjacent: List[Vertex] = []
        self.info : VertexInfo = info

    def __eq__(self, other):
        # 如果Vertex的名称(name参数)相同，我们就认为两个Vertex是一样的
        if type(self) != type(other): return False
        if self.name == other.name:
            # 如果两个顶点的名称相同，我们将会检查这两个节点的坐标和相邻节点是否相同
            # 如若不同，将会在终端产生warning, 但程序并不报错
            if self.x != other.x or self.y != other.y or self.z != other.z:
                logging.warning("Inconsistent position between Vertexes {}:\n"
                                "  [self]: {}\n [other]: {}".format(self.name, (self.x, self.y, self.z),
                                                                   (other.x, other.y, other.z)))
            if self.adjacent != other.adjacent:
                logging.warning("Inconsistent adjacent list between Vertex {}:\n"
                                " [self ]: {}\n [other]: {}".format(self.name, self.adjacent, other.adjacent))
            return True
        return False
    
    def __str__(self):
        # 指定调用print函数时，程序终端将会输出的string
        return "class Vertex:\n\tname: {}\n\tposition: {}\n\tadjacent vertex: {}".\
            format(self.name, (self.x, self.y, self.z), [_.name for _ in self.adjacent])
    
    def add_adjacent(self, vertex):
        # 向顶点的邻近表中添加节点
        assert type(self) == type(vertex)
        if vertex not in self.adjacent:
            self.adjacent.append(vertex)
            return True
        return False

    @property
    def n_adjacent(self):
        return len(self.adjacent)

# %% [markdown]
# ## 2.4 Edge类
# - <font color=white size=4 face=雅黑>对应着图上的一条无向边，存有`Edge`的两个顶点,**name**参数为两个顶点对应**name**参数构成的Set；</font>
# - <font color=white size=4 face=雅黑>如果两个Edge类的 **name**相等，那么我们就认为这两条边相等，这里**不考虑**`Edge`当中顶点的先后顺序；</font>
# - <font color=white size=4 face=雅黑>如果 **e**是一个`Edge`类的实例，则可以通过 **print(e)** 查看该条边的信息；</font>

# %%
class Edge(object):
    def __init__(self, v1: Vertex, v2: Vertex):
        self.v1 = v1
        self.v2 = v2
        self.name: Set = {v1.name, v2.name}
        self.length_init = self.length

    def __eq__(self, other):
        if type(self) != type(other): return False
        return self.name == other.name

    def __str__(self):
        return "class Edge: \n\t name = {} \n\t v1.position = {} \n\t v2.position = {} \n\t length = {}".\
        format(self.name, self.v1.position, self.v2.position, self.length)

    @property
    def length(self) -> LengthType:
        # the length of the edge
        return ((self.v1.x - self.v2.x) ** 2 + (self.v1.y - self.v2.y) ** 2 + (self.v1.z - self.v2.z) ** 2) ** 0.5

# %% [markdown]
# Edge类的测试

# %%
e0 = Edge(Origin, Origin)
print(e0)
# Out:
# class Edge:
# 	 name = {'Origin'}
# 	 v1.position = (0.0, 0.0, 0.0)
# 	 v2.position = (0.0, 0.0, 0.0)
# 	 length = 0.0

# %% [markdown]
# ## 2.5 Graph类
# - <font color=white size=4 face=雅黑>可以直接输入边和顶点的列表，也可以通过顶点的列表构造出边；</font>

# %%
class Graph(object):
    def __init__(self, vertex_list: Optional[List[Vertex]]=[], 
                       edge_list  : Optional[List[Edge  ]]=[]):
        self.vertex_list: List[Vertex] = vertex_list
        self.edge_list  : List[Edge  ] = [] if edge_list == None else edge_list

    def update_edge(self):
        logging.info("Updating Edges...")
        from tqdm import tqdm
        for v in tqdm(self.vertex_list):
            for v_adjacent in v.adjacent:
                assert v in v_adjacent.adjacent
                edge = Edge(v, v_adjacent)
                if edge not in self.edge_list:
                    self.edge_list.append(edge)
    
    @property
    def n_edge(self):
        return len(self.edge_list)

    @property
    def n_vertex(self):
        return len(self.vertex_list)

# %% [markdown]
# # 3. 数据的读入

# %% [markdown]
# ## 3.1 从csv文件读入数据，储存在pandas.DataFrame之中，留作备份

# %%
import pandas as pd

vertex_frame        = pd.read_csv('./data/vertex.csv'       ,header=0,sep=',')
ground_vertex_frame = pd.read_csv('./data/vertex_ground.csv',header=0,sep=',')
face_vertex_frame   = pd.read_csv('./data/face.csv'         ,header=0,sep=',')

# %%
vertex_frame.head()
# Out:
#   Index       X       Y         Z
# 0    A0  0.0000   0.000 -300.4000
# 1    B1  6.1078   8.407 -300.2202
# 2    C1  9.8827  -3.211 -300.2202
# 3    D1  0.0000 -10.391 -300.2202
# 4    E1 -9.8827  -3.211 -300.2202

# %%
ground_vertex_frame.head()
# Out:
#   Index       Xg      Yg        Zg
# 0    A0   0.0000   0.000 -304.7218
# 1    B1   6.1935   8.525 -304.4318
# 2    C1  10.0227  -3.256 -304.4747
# 3    D1   0.0000 -10.538 -304.4868
# 4    E1 -10.0214  -3.256 -304.4337

# %%
face_vertex_frame.head()
# Out:
#   Index1 Index2 Index3
# 0     A0     B1     C1
# 1     A0     B1     A1
# 2     A0     C1     D1
# 3     A0     D1     E1
# 4     A0     E1     A1

# %%
isinstance(face_vertex_frame, pd.DataFrame)
# Out:
# True

# %% [markdown]
# ## 3.2 从pandas.DataFrame之中读出数据，构建出图的网络结构

# %% [markdown]
# ### 3.2.1 读取顶点（主索节点）列表 vertex_frame, 促动器列表 ground_vertex_frame 的数据

# %%
from tqdm import tqdm
vertex_list: List[Vertex] = []
print("Getting Information...")
for idx in tqdm(range(len(vertex_frame))):
    # 获取主索节点的位置信息
    vx = vertex_frame["X"][idx]
    vy = vertex_frame["Y"][idx]
    vz = vertex_frame["Z"][idx]
    init_v_pos = np.array([vx, vy, vz], dtype=np.float64)
    # 获取主索节点促动器固定处位置的信息
    assert vertex_frame["Index"][idx] == ground_vertex_frame["Index"][idx]
    gvx = ground_vertex_frame["Xg"][idx]
    gvy = ground_vertex_frame["Yg"][idx]
    gvz = ground_vertex_frame["Zg"][idx]
    gv_pos = np.array([gvx, gvy, gvz], dtype=np.float64)
    vertex_info = VertexInfo(index = idx, status=-1, 
                             vertex_init_pos   =init_v_pos,
                             vertex_ground_pos =gv_pos)
    vertex_list.append(Vertex(name=vertex_frame["Index"][idx],
                              x=vx,
                              y=vy,
                              z=vz,
                              info=vertex_info))

print("len(vertex_list) = ", len(vertex_list))
# Out:
# Getting Information...
# 100%|██████████| 2226/2226 [00:00<00:00, 23215.65it/s]
# len(vertex_list) =  2226

# %% [markdown]
# ### 3.2.2 通过 face_vertex_frame 更新顶点之间的近邻关系

# %%
print("updating adjacent relationships...")
for face_idx in tqdm(range(len(face_vertex_frame))):
    # 读取三角反射面三个顶点的 name 参数
    v1_name = face_vertex_frame["Index1"][face_idx]
    v2_name = face_vertex_frame["Index2"][face_idx]
    v3_name = face_vertex_frame["Index3"][face_idx]
    # 在 vertex_list 之中根据 name参数 找到相应的顶点，
    v1, v2, v3 = None, None, None
    for v in vertex_list:
        if v.name == v1_name: v1 = v
        if v.name == v2_name: v2 = v
        if v.name == v3_name: v3 = v
        if v1 and v2 and v3: break
    
    # 更新近邻节点的信息
    assert v1 and v2 and v3
    v1.add_adjacent(v2)
    v1.add_adjacent(v3)
    v2.add_adjacent(v3)
    v2.add_adjacent(v1)
    v3.add_adjacent(v1)
    v3.add_adjacent(v2)
# Out:
# updating adjacent relationships...
# 100%|██████████| 4300/4300 [00:00<00:00, 4564.46it/s]

# %% [markdown]
# ### 3.2.3 构造图

# %%
FASTnet = Graph(vertex_list = vertex_list)
FASTnet.update_edge()
print("n_edge   = ", FASTnet.n_edge)
print("n_vertex = ", FASTnet.n_vertex)
# Out:
# 100%|██████████| 2226/2226 [00:07<00:00, 290.58it/s]
# n_edge   =  6525
# n_vertex =  2226

# %% [markdown]
# ## 3.3 图的测试

# %%
for i in range(2):
    print(FASTnet.vertex_list[i])
    print(FASTnet.edge_list[i])
# Out:
# class Vertex:
# 	name: A0
# 	position: (0.0, 0.0, -300.4)
# 	adjacent vertex: ['B1', 'C1', 'A1', 'D1', 'E1']
# class Edge:
# 	 name = {'B1', 'A0'}
# 	 v1.position = (0.0, 0.0, -300.4)
# 	 v2.position = (6.1078, 8.407, -300.2202)
# 	 length = 10.393036028033388
# class Vertex:
# 	name: B1
# 	position: (6.1078, 8.407, -300.2202)
# 	adjacent vertex: ['C1', 'A0', 'A1', 'B3', 'A3', 'B2']
# class Edge:
# 	 name = {'C1', 'A0'}
# 	 v1.position = (0.0, 0.0, -300.4)
# 	 v2.position = (9.8827, -3.211, -300.2202)
# 	 length = 10.392815226395589

# %% [markdown]
# # 4. 能量计算函数的得到

# %% [markdown]
# ## 4.1 判断节点是否处于工作区，分别储存

# %%
def isworking(x:ScalorType,y:ScalorType,z:ScalorType):
    return (x ** 2 + y ** 2) < 150**2

# %%
vertex_list_working : List[Vertex] = []
vertex_list_fixing : List[Vertex]  = []
vertex_list_idling : List[Vertex]  = []
for i, vertex in enumerate(FASTnet.vertex_list):
    if isworking(*vertex.info.vertex_init_pos):
        vertex.info._status=0
        vertex_list_working.append(vertex)
    elif vertex.n_adjacent < 5:
        vertex.info._status=2
        vertex_list_fixing.append(vertex)
    else:
        vertex.info._status=1
        vertex_list_idling.append(vertex)

print(len(vertex_list_working))
print(len(vertex_list_fixing))
print(len(vertex_list_idling))
# Out:
# 706
# 130
# 1390

# %% [markdown]
# <font color=white size=4 face=雅黑>测试</font>

# %%
print(vertex_list_working[0].info.status)
print(vertex_list_fixing[0].info.status)
print(vertex_list_idling[0].info.status)
# Out:
# working
# fixing
# idling

# %% [markdown]
# ## 4.2 定义单根连接索的能量, 并用vmap扩展

# %%
from jax import lax
# 超参数

k_timer = 1.
offset_ratio = 7E-4

# 参数
A = 2.25 * 3.1415 * 1E-4  # 横截面积（米^2）
# E = 1.8E11             # 杨氏模量（Pa）
E = 1.8E4             # 杨氏模量（Pa）

c1 = E * A

def edge_energy(length:LengthType, length_init:LengthType):
    delta_L = jnp.abs(length - length_init)
    lc = offset_ratio * length_init
    K = c1 / lc

    return lax.cond(delta_L < lc, lambda x: 0.5 * K * delta_L ** 2, lambda x: 0.5 * K * delta_L ** 2, None)

    # if delta_L < lc:
    #     return 0.5 * K * delta_L ** 2
    # else:
    #     return c

# %% [markdown]
# - <font color=white size=4 face=雅黑>通过vmap扩展到多个长度的map</font>

# %%
edges_energy = jax.vmap(edge_energy, in_axes = (0,0), out_axes=0, )

# %% [markdown]
# <font color=white size=4 face=雅黑>可视化</font>

# %%
import matplotlib.pyplot as plt

length_init_test  = 10.
length_max_offset_test = length_init_test * offset_ratio * 2.14
length_delta_test = jnp.linspace(-length_max_offset_test, length_max_offset_test, 1001)
energy = []
for dl in length_delta_test:
    e = edge_energy(length_init_test+dl, length_init_test)
    energy.append(e)


plt.plot(length_delta_test, energy)
plt.xlabel("length offset")
plt.ylabel("energy")
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Text(0, 0.5, 'energy')

# %% [markdown]
# ## 4.3 确定目标抛物面的形状
# - <font color=white size=4 face=雅黑>此处未给出过程，可以先承认下来</font>

# %%
def calc_z(x, y, h=300.89097588, R=300.4):
    return (x**2+y**2) / (4*(h-R+0.466*R))-h

# %% [markdown]
# ## 4.4 无约束条件下的能量函数

# %% [markdown]
# <font color=white size=4 face=雅黑>计算初始长度数组 init_length_array， 数组顺序与 graph 之中的 edge_list 同</font>

# %%
# 注意，因为不需要微分，这里所有的长度都是 numpy.array 格式
init_pos_array = np.array(vertex_frame.iloc[:,1:], dtype=np.float64)
init_v1_idx = [e.v1.info.idx for e in FASTnet.edge_list]
init_v2_idx = [e.v2.info.idx for e in FASTnet.edge_list]
init_v1_pos_array = init_pos_array[init_v1_idx,:]  # (nedge, 3)
init_v2_pos_array = init_pos_array[init_v2_idx,:]  # (nedge, 3)
init_length_array = np.sum((init_v1_pos_array - init_v2_pos_array)**2, axis=-1) ** 0.5  # (nedge,)

# 输出测试
print("len = ", len(init_length_array))
print("max = ", max(init_length_array))
print("min = ", min(init_length_array))
print(init_length_array[:5])
# Out:
# len =  6525
# max =  12.417912939379152
# min =  10.392106868195688
# [10.39303603 10.39281523 10.39303603 10.39255546 10.39281523]

# %% [markdown]
# <font color=white size=4 face=雅黑>初始条件下主索节点的位置，用jnp.ndarray格式储存</font>

# %%
pos_array = jnp.array(vertex_frame.iloc[:,1:])
print(pos_array.shape)
# Out:
# (2226, 3)

# %% [markdown]
# <font color=white size=4 face=雅黑>无约束条件下能量函数的生成</font>

# %%
def gen_net_energy(net: Graph, summing=True):
    adjacent_idx1 = [e.v1.info.idx for e in net.edge_list]
    adjacent_idx2 = [e.v2.info.idx for e in net.edge_list]
    
    def net_energy(pos_array: jnp.ndarray, init_length_array = init_length_array):
        # pos_array 的 shape 是 (nvertex, 3)
        v1_array = pos_array[adjacent_idx1,:]  # (nedge, 3)
        v2_array = pos_array[adjacent_idx2,:]  # (nedge, 3)
        length_array = jnp.sum((v1_array - v2_array)**2, axis=-1) ** 0.5  # (nedge,)：实际连接索们的长度
        ene = edges_energy(length_array, init_length_array)

        if summing:
            return jnp.sum(ene)
        return ene
    return net_energy

# %% [markdown]
# ### 测试

# %%
net_energy = gen_net_energy(FASTnet, summing=False)  # 无约束条件下能量的计算函数
ene_unrestricted = net_energy(pos_array)
print(ene_unrestricted)
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %% [markdown]
# ## 4.5 给无约束的能量函数添加约束，变为有约束能量函数
# - <font color=white size=4 face=雅黑>如此做目的在于方便扩展，同时提高效率</font>

# %% [markdown]
# ### 4.5.1 整理元素顺序

# %%
# 之前已经得到的list:
#   工作区： vertex_list_working
#   过渡区： vertex_list_idling
#   固定区： vertex_list_fixing


# 获取不同区域主索节点们的index
working_vertex_index_list = [v.info.idx for v in vertex_list_working]
fixing_vertex_index_list  = [v.info.idx for v in vertex_list_fixing ]
idling_vertex_index_list  = [v.info.idx for v in vertex_list_idling ]

# 将这些index组合在一起
vertex_index_list: List[int] = []
vertex_index_list.extend(working_vertex_index_list)  # 先是 working
vertex_index_list.extend(idling_vertex_index_list)   # 再放 idling
vertex_index_list.extend(fixing_vertex_index_list)   # 最后 fixing
print(len(vertex_index_list))
print(vertex_index_list[:5])
# Out:
# 2226
# [0, 1, 2, 3, 4]

# %%
# 上述的 vertex_index_list 指明了所有的 vertex 在以 [working, idling, fixing]的顺序组合后，相比于最初，以一种什么样的方式被打乱，相当于定义了一个置换操作p
# 如果我们想要让已经被打乱的 vertex 位置数组重新恢复原本的顺序，就需要求出该置换操作的逆 p_inverse:

def inverse_index(p:List[int]):
    p = np.array(p)
    p_original = np.arange(len(p))
    operation = np.vstack([p_original, p]).T.tolist()
    operation_inv = sorted(operation, key=lambda x:x[1], reverse=False)
    p_inverse = [op[0] for op in operation_inv]
    return p_inverse

vertex_index_list_inverse = inverse_index(vertex_index_list)
plt.plot(vertex_index_list)
plt.plot(vertex_index_list_inverse)
# plt.plot(np.arange(len(vertex_index_list_inverse)), vertex_index_list_inverse)

# %%
# 生成约束条件下的函数
fixing_pos_array = jnp.asarray([[v.x, v.y, v.z] for v in vertex_list_fixing])

def gen_net_energy_restricted(energy_fcn:Callable, calc_z_working:Callable):
    
    def net_energy_restricted(working_xy_array:jnp.ndarray, idling_pos_array:jnp.ndarray):
        # 我们先按照约束把工作区主索节点的坐标补全
        working_z_array = calc_z_working(working_xy_array[:,0],working_xy_array[:,1])[:,jnp.newaxis]
        working_pos_array = jnp.hstack([working_xy_array, working_z_array])

        # 将 pos_array 分别 stack 在一起
        pos_array = jnp.vstack([working_pos_array, idling_pos_array, fixing_pos_array])

        # 将 pos_array 按照原本的顺序排列
        pos_array_ordered = pos_array[vertex_index_list_inverse, :]

        # 计算得到能量函数
        ene = energy_fcn(pos_array_ordered)
        return ene
    return net_energy_restricted

# %% [markdown]
# ### 4.5.3 测试能量函数
# - <font color=white size=4 face=雅黑>测试</font>

# %%
# 之前已经得到的list:
#   工作区： vertex_list_working
#   过渡区： vertex_list_idling
#   固定区： vertex_list_fixing

working_xy_array = jnp.array([[v.x, v.y] for v in vertex_list_working])
idling_pos_array = jnp.array([[v.x, v.y, v.z] for v in vertex_list_idling])

# 能量分布可视化
net_energy = gen_net_energy(FASTnet, summing=False)
net_energy_restricted = gen_net_energy_restricted(net_energy, calc_z) # 有约束条件下能量的计算函数
plt.plot(net_energy_restricted(working_xy_array=working_xy_array, idling_pos_array=idling_pos_array))

# %% [markdown]
# # 5. 梯度下降，开始计算

# %%
from jax import grad, jit

get_E = gen_net_energy(FASTnet, summing=True)
get_E = gen_net_energy_restricted(get_E, calc_z) # 有约束条件下能量的计算函数


get_E = jit(get_E)
get_dE = jit(grad(get_E,argnums=(0,1)))

# %%
working_xy_array = jnp.array([[v.x, v.y] for v in vertex_list_working])
idling_pos_array = jnp.array([[v.x, v.y, v.z] for v in vertex_list_idling])


E = get_E(working_xy_array, idling_pos_array)
dE = get_dE(working_xy_array, idling_pos_array)
print(E)
print(dE)
# Out:
# 6280.706218473625
# (DeviceArray([[ 0.00000000e+00, -7.06247815e-04],
#              [-2.15074784e+00, -2.96351601e+00],
#              [-3.47943983e+00,  1.12924452e+00],
#              ...,
#              [ 7.37027435e+02, -2.97022100e+02],
#              [ 8.11308818e+02, -3.65728149e+02],
#              [ 8.82014868e+02, -6.08981229e+02]], dtype=float64), DeviceArray([[-2.24765298e+02,  3.54783728e+02,  2.61916820e+02],
#              [ 2.24765298e+02,  3.54783728e+02,  2.61916820e+02],
#              [ 2.44760766e+02,  3.36853682e+02,  2.72550917e+02],
#              ...,
#              [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#              [ 1.49255462e-12,  2.54040196e-12,  4.01189612e-13],
#              [-1.49255462e-12, -2.54040196e-12, -4.01189612e-13]],            dtype=float64))

# %%
from copy import deepcopy
working_xy_array_copy = deepcopy(working_xy_array)
idling_pos_array_copy = deepcopy(idling_pos_array)

# %%
# 重新开始
working_xy_array = deepcopy(working_xy_array_copy)
idling_pos_array = deepcopy(idling_pos_array_copy)

# %%
d_working_xy_array, d_idling_pos_array = get_dE(working_xy_array, idling_pos_array)
print(d_working_xy_array)
print(working_xy_array)
# Out:
# [[ 0.00000000e+00 -7.06247815e-04]
#  [-2.15074784e+00 -2.96351601e+00]
#  [-3.47943983e+00  1.12924452e+00]
#  ...
#  [ 7.37027435e+02 -2.97022100e+02]
#  [ 8.11308818e+02 -3.65728149e+02]
#  [ 8.82014868e+02 -6.08981229e+02]]
# [[   0.        0.    ]
#  [   6.1078    8.407 ]
#  [   9.8827   -3.211 ]
#  ...
#  [-130.8804   61.454 ]
#  [-126.8337   72.541 ]
#  [-122.6154   83.493 ]]

# %%
epochs = 200
steps = 200
ene_list = []

import optax
opt = optax.adam(lr=0.00001)


m_work = 0.   # initialize 1^st moment vector
m_idle = 0.
v_work = 0.   # initialize 2^nd moment vector
v_idle = 0.


# ene = get_E(working_xy_array, idling_pos_array)
# print("[{}][{}]: ene = {}".format(0, 0, ene))


for epoch in range(epochs):
    for step in range(steps):
        # 获得梯度
        d_working_xy_array, d_idling_pos_array = get_dE(working_xy_array, idling_pos_array)

        # # Adam优化
        m_work = beta1 * m_work + (1. - beta1) * d_working_xy_array
        v_work = beta2 * v_work + (1. - beta2) * d_working_xy_array ** 2
        m_work = m_work / (1.-beta1)
        v_work = v_work / (1.-beta2)

        m_idle = beta1 * m_idle + (1. - beta1) * d_idling_pos_array
        v_idle = beta2 * v_idle + (1. - beta2) * d_idling_pos_array ** 2
        m_idle = m_idle / (1.-beta1)
        v_idle = v_idle / (1.-beta2)
    
        # 梯度下降
        working_xy_array = working_xy_array - lr * m_work / (v_work**0.5 + eps)
        idling_pos_array = idling_pos_array - lr * m_idle / (v_idle**0.5 + eps)    
        
        # # # 直接梯度下降
        # idling_pos_array = idling_pos_array - lr * d_idling_pos_array
        # working_xy_array = working_xy_array - lr * d_working_xy_array
        
        if (step + 1) % 10 == 0:
            ene = get_E(working_xy_array, idling_pos_array)
            ene_list.append(ene)
            print("[{}][{}]: ene = {}, v_idle {}, m_idle {}"\
                .format(epoch+1, step+1, float(ene), v_idle[0][0], m_idle[0][0]))
    # if epoch < 100:
    #     lr = lr * 1.1
    # elif epoch < 150:
    #     lr = lr * 1.05
# Out:
# [1][10]: ene = 6280.445208059803, v_idle 5.011674279098965e+31, m_idle -97963197697.98886
# [1][20]: ene = 6280.445207065911, v_idle 4.9617824613007665e+61, m_idle -3.415765497033875e+20
# [1][30]: ene = 6280.445207065911, v_idle 4.9123873225253036e+91, m_idle -1.1910037852531754e+30
# [1][40]: ene = 6280.445207065911, v_idle 4.863483918273406e+121, m_idle -4.1527734199527374e+39
# [1][50]: ene = 6280.445207065911, v_idle 4.8150673532689877e+151, m_idle -1.447982558157866e+49
# [1][60]: ene = 6280.445207065911, v_idle 4.767132780969022e+181, m_idle -5.048802996704937e+58
# [1][70]: ene = 6280.445207065911, v_idle 4.7196754030783965e+211, m_idle -1.7604087532632873e+68
# [1][80]: ene = 6280.445207065911, v_idle 4.6726904690696045e+241, m_idle -6.138165780262304e+77
# [1][90]: ene = 6280.445207065911, v_idle 4.626173275707207e+271, m_idle -2.1402460693370654e+87
# [1][100]: ene = 6280.445207065911, v_idle 4.580119166577039e+301, m_idle -7.462576608866061e+96
# [1][110]: ene = 6280.445207065911, v_idle inf, m_idle -2.602039571106172e+106
# [1][120]: ene = 6280.445207065911, v_idle inf, m_idle -9.072750987317757e+115
# [1][130]: ene = 6280.445207065911, v_idle inf, m_idle -3.1634726616736987e+125
# [1][140]: ene = 6280.445207065911, v_idle inf, m_idle -1.1030347129713828e+135
# [1][150]: ene = 6280.445207065911, v_idle inf, m_idle -3.846044230950139e+144
# [1][160]: ene = 6280.445207065911, v_idle inf, m_idle -1.341032703003302e+154
# [1][170]: ene = 6280.445207065911, v_idle inf, m_idle -4.67589191006279e+163
# [1][180]: ene = 6280.445207065911, v_idle inf, m_idle -1.6303826972769068e+173
# [1][190]: ene = 6280.445207065911, v_idle inf, m_idle -5.684792956525437e+182
# [1][200]: ene = 6280.445207065911, v_idle inf, m_idle -1.9821647403727614e+192
# [2][10]: ene = 6280.445207065911, v_idle inf, m_idle -6.911381096943977e+201
# [2][20]: ene = 6280.445207065911, v_idle inf, m_idle -2.4098495798190587e+211
# [2][30]: ene = 6280.445207065911, v_idle inf, m_idle -8.40262592366952e+220
# [2][40]: ene = 6280.445207065911, v_idle inf, m_idle -2.9298144998089165e+230
# [2][50]: ene = 6280.445207065911, v_idle inf, m_idle -1.0215631495757373e+240
# [2][60]: ene = 6280.445207065911, v_idle inf, m_idle -3.5619704545771188e+249
# [2][70]: ene = 6280.445207065911, v_idle inf, m_idle -1.2419823017842405e+259
# [2][80]: ene = 6280.445207065911, v_idle inf, m_idle -4.3305245161793746e+268
# [2][90]: ene = 6280.445207065911, v_idle inf, m_idle -1.509960533116235e+278
# [2][100]: ene = 6280.445207065911, v_idle inf, m_idle -5.2649068329953454e+287
# [2][110]: ene = 6280.445207065911, v_idle inf, m_idle -1.8357595018006527e+297
# [2][120]: ene = 6280.445207065911, v_idle inf, m_idle -6.400897594866061e+306
# [2][130]: ene = nan, v_idle nan, m_idle nan
# [2][140]: ene = nan, v_idle nan, m_idle nan
# [2][150]: ene = nan, v_idle nan, m_idle nan
# [2][160]: ene = nan, v_idle nan, m_idle nan
# [2][170]: ene = nan, v_idle nan, m_idle nan
# [2][180]: ene = nan, v_idle nan, m_idle nan
# [2][190]: ene = nan, v_idle nan, m_idle nan
# [2][200]: ene = nan, v_idle nan, m_idle nan
# [3][10]: ene = nan, v_idle nan, m_idle nan
# [3][20]: ene = nan, v_idle nan, m_idle nan
# [3][30]: ene = nan, v_idle nan, m_idle nan
# [3][40]: ene = nan, v_idle nan, m_idle nan
# [3][50]: ene = nan, v_idle nan, m_idle nan
# [3][60]: ene = nan, v_idle nan, m_idle nan
# [3][70]: ene = nan, v_idle nan, m_idle nan
# [3][80]: ene = nan, v_idle nan, m_idle nan
# [3][90]: ene = nan, v_idle nan, m_idle nan
# [3][100]: ene = nan, v_idle nan, m_idle nan
# [3][110]: ene = nan, v_idle nan, m_idle nan
# [3][120]: ene = nan, v_idle nan, m_idle nan
# [3][130]: ene = nan, v_idle nan, m_idle nan
# [3][140]: ene = nan, v_idle nan, m_idle nan
# [3][150]: ene = nan, v_idle nan, m_idle nan
# [3][160]: ene = nan, v_idle nan, m_idle nan
# [3][170]: ene = nan, v_idle nan, m_idle nan
# [3][180]: ene = nan, v_idle nan, m_idle nan
# [3][190]: ene = nan, v_idle nan, m_idle nan
# [3][200]: ene = nan, v_idle nan, m_idle nan
# [4][10]: ene = nan, v_idle nan, m_idle nan
# [4][20]: ene = nan, v_idle nan, m_idle nan
# [4][30]: ene = nan, v_idle nan, m_idle nan
# [4][40]: ene = nan, v_idle nan, m_idle nan
# [4][50]: ene = nan, v_idle nan, m_idle nan
# [4][60]: ene = nan, v_idle nan, m_idle nan
# [4][70]: ene = nan, v_idle nan, m_idle nan
# [4][80]: ene = nan, v_idle nan, m_idle nan
# [4][90]: ene = nan, v_idle nan, m_idle nan
# [4][100]: ene = nan, v_idle nan, m_idle nan
# [4][110]: ene = nan, v_idle nan, m_idle nan
# [4][120]: ene = nan, v_idle nan, m_idle nan
# [4][130]: ene = nan, v_idle nan, m_idle nan
# [4][140]: ene = nan, v_idle nan, m_idle nan
# [4][150]: ene = nan, v_idle nan, m_idle nan
# [4][160]: ene = nan, v_idle nan, m_idle nan
# [4][170]: ene = nan, v_idle nan, m_idle nan
# [4][180]: ene = nan, v_idle nan, m_idle nan
# [4][190]: ene = nan, v_idle nan, m_idle nan
# [4][200]: ene = nan, v_idle nan, m_idle nan
# [5][10]: ene = nan, v_idle nan, m_idle nan
# [5][20]: ene = nan, v_idle nan, m_idle nan
# [5][30]: ene = nan, v_idle nan, m_idle nan
# [5][40]: ene = nan, v_idle nan, m_idle nan
# [5][50]: ene = nan, v_idle nan, m_idle nan
# [5][60]: ene = nan, v_idle nan, m_idle nan
# [5][70]: ene = nan, v_idle nan, m_idle nan
# [5][80]: ene = nan, v_idle nan, m_idle nan
# [5][90]: ene = nan, v_idle nan, m_idle nan
# [5][100]: ene = nan, v_idle nan, m_idle nan
# [5][110]: ene = nan, v_idle nan, m_idle nan
# [5][120]: ene = nan, v_idle nan, m_idle nan
# [5][130]: ene = nan, v_idle nan, m_idle nan
# [5][140]: ene = nan, v_idle nan, m_idle nan
# [5][150]: ene = nan, v_idle nan, m_idle nan
# [5][160]: ene = nan, v_idle nan, m_idle nan
# [5][170]: ene = nan, v_idle nan, m_idle nan
# [5][180]: ene = nan, v_idle nan, m_idle nan
# [5][190]: ene = nan, v_idle nan, m_idle nan
# [5][200]: ene = nan, v_idle nan, m_idle nan
# [6][10]: ene = nan, v_idle nan, m_idle nan
# [6][20]: ene = nan, v_idle nan, m_idle nan
# [6][30]: ene = nan, v_idle nan, m_idle nan
# [6][40]: ene = nan, v_idle nan, m_idle nan
# [6][50]: ene = nan, v_idle nan, m_idle nan
# [6][60]: ene = nan, v_idle nan, m_idle nan
# [6][70]: ene = nan, v_idle nan, m_idle nan
# [6][80]: ene = nan, v_idle nan, m_idle nan
# [6][90]: ene = nan, v_idle nan, m_idle nan
# [6][100]: ene = nan, v_idle nan, m_idle nan
# [6][110]: ene = nan, v_idle nan, m_idle nan
# [6][120]: ene = nan, v_idle nan, m_idle nan
# [6][130]: ene = nan, v_idle nan, m_idle nan
# [6][140]: ene = nan, v_idle nan, m_idle nan
# [6][150]: ene = nan, v_idle nan, m_idle nan
# [6][160]: ene = nan, v_idle nan, m_idle nan
# [6][170]: ene = nan, v_idle nan, m_idle nan
# [6][180]: ene = nan, v_idle nan, m_idle nan
# [6][190]: ene = nan, v_idle nan, m_idle nan
# [6][200]: ene = nan, v_idle nan, m_idle nan
# [7][10]: ene = nan, v_idle nan, m_idle nan
# [7][20]: ene = nan, v_idle nan, m_idle nan
# [7][30]: ene = nan, v_idle nan, m_idle nan
# [7][40]: ene = nan, v_idle nan, m_idle nan
# [7][50]: ene = nan, v_idle nan, m_idle nan
# [7][60]: ene = nan, v_idle nan, m_idle nan
# [7][70]: ene = nan, v_idle nan, m_idle nan
# [7][80]: ene = nan, v_idle nan, m_idle nan
# [7][90]: ene = nan, v_idle nan, m_idle nan
# [7][100]: ene = nan, v_idle nan, m_idle nan
# [7][110]: ene = nan, v_idle nan, m_idle nan
# [7][120]: ene = nan, v_idle nan, m_idle nan
# [7][130]: ene = nan, v_idle nan, m_idle nan
# [7][140]: ene = nan, v_idle nan, m_idle nan
# [7][150]: ene = nan, v_idle nan, m_idle nan
# [7][160]: ene = nan, v_idle nan, m_idle nan
# [7][170]: ene = nan, v_idle nan, m_idle nan
# [7][180]: ene = nan, v_idle nan, m_idle nan
# [7][190]: ene = nan, v_idle nan, m_idle nan
# [7][200]: ene = nan, v_idle nan, m_idle nan
# [8][10]: ene = nan, v_idle nan, m_idle nan
# [8][20]: ene = nan, v_idle nan, m_idle nan
# [8][30]: ene = nan, v_idle nan, m_idle nan
# [8][40]: ene = nan, v_idle nan, m_idle nan
# [8][50]: ene = nan, v_idle nan, m_idle nan
# [8][60]: ene = nan, v_idle nan, m_idle nan
# [8][70]: ene = nan, v_idle nan, m_idle nan
# [8][80]: ene = nan, v_idle nan, m_idle nan
# [8][90]: ene = nan, v_idle nan, m_idle nan
# [8][100]: ene = nan, v_idle nan, m_idle nan
# [8][110]: ene = nan, v_idle nan, m_idle nan
# [8][120]: ene = nan, v_idle nan, m_idle nan
# [8][130]: ene = nan, v_idle nan, m_idle nan
# [8][140]: ene = nan, v_idle nan, m_idle nan
# [8][150]: ene = nan, v_idle nan, m_idle nan
# [8][160]: ene = nan, v_idle nan, m_idle nan
# [8][170]: ene = nan, v_idle nan, m_idle nan
# [8][180]: ene = nan, v_idle nan, m_idle nan
# [8][190]: ene = nan, v_idle nan, m_idle nan
# [8][200]: ene = nan, v_idle nan, m_idle nan
# [9][10]: ene = nan, v_idle nan, m_idle nan
# [9][20]: ene = nan, v_idle nan, m_idle nan
# [9][30]: ene = nan, v_idle nan, m_idle nan
# [9][40]: ene = nan, v_idle nan, m_idle nan
# [9][50]: ene = nan, v_idle nan, m_idle nan
# [9][60]: ene = nan, v_idle nan, m_idle nan
# [9][70]: ene = nan, v_idle nan, m_idle nan
# [9][80]: ene = nan, v_idle nan, m_idle nan
# [9][90]: ene = nan, v_idle nan, m_idle nan
# [9][100]: ene = nan, v_idle nan, m_idle nan
# [9][110]: ene = nan, v_idle nan, m_idle nan
# [9][120]: ene = nan, v_idle nan, m_idle nan
# [9][130]: ene = nan, v_idle nan, m_idle nan
# [9][140]: ene = nan, v_idle nan, m_idle nan
# [9][150]: ene = nan, v_idle nan, m_idle nan
# [9][160]: ene = nan, v_idle nan, m_idle nan
# [9][170]: ene = nan, v_idle nan, m_idle nan
# [9][180]: ene = nan, v_idle nan, m_idle nan
# [9][190]: ene = nan, v_idle nan, m_idle nan
# [9][200]: ene = nan, v_idle nan, m_idle nan
# [10][10]: ene = nan, v_idle nan, m_idle nan
# [10][20]: ene = nan, v_idle nan, m_idle nan
# [10][30]: ene = nan, v_idle nan, m_idle nan
# [10][40]: ene = nan, v_idle nan, m_idle nan
# [10][50]: ene = nan, v_idle nan, m_idle nan
# [10][60]: ene = nan, v_idle nan, m_idle nan
# [10][70]: ene = nan, v_idle nan, m_idle nan
# [10][80]: ene = nan, v_idle nan, m_idle nan
# [10][90]: ene = nan, v_idle nan, m_idle nan
# [10][100]: ene = nan, v_idle nan, m_idle nan
# [10][110]: ene = nan, v_idle nan, m_idle nan
# [10][120]: ene = nan, v_idle nan, m_idle nan
# [10][130]: ene = nan, v_idle nan, m_idle nan
# [10][140]: ene = nan, v_idle nan, m_idle nan
# [10][150]: ene = nan, v_idle nan, m_idle nan
# [10][160]: ene = nan, v_idle nan, m_idle nan
# [10][170]: ene = nan, v_idle nan, m_idle nan
# [10][180]: ene = nan, v_idle nan, m_idle nan
# [10][190]: ene = nan, v_idle nan, m_idle nan
# [10][200]: ene = nan, v_idle nan, m_idle nan
# [11][10]: ene = nan, v_idle nan, m_idle nan
# [11][20]: ene = nan, v_idle nan, m_idle nan
# [11][30]: ene = nan, v_idle nan, m_idle nan
# [11][40]: ene = nan, v_idle nan, m_idle nan
# [11][50]: ene = nan, v_idle nan, m_idle nan
# [11][60]: ene = nan, v_idle nan, m_idle nan
# [11][70]: ene = nan, v_idle nan, m_idle nan
# [11][80]: ene = nan, v_idle nan, m_idle nan
# [11][90]: ene = nan, v_idle nan, m_idle nan
# [11][100]: ene = nan, v_idle nan, m_idle nan
# [11][110]: ene = nan, v_idle nan, m_idle nan
# [11][120]: ene = nan, v_idle nan, m_idle nan
# [11][130]: ene = nan, v_idle nan, m_idle nan
# [11][140]: ene = nan, v_idle nan, m_idle nan
# [11][150]: ene = nan, v_idle nan, m_idle nan
# [11][160]: ene = nan, v_idle nan, m_idle nan
# [11][170]: ene = nan, v_idle nan, m_idle nan
# [11][180]: ene = nan, v_idle nan, m_idle nan
# [11][190]: ene = nan, v_idle nan, m_idle nan
# [11][200]: ene = nan, v_idle nan, m_idle nan
# [12][10]: ene = nan, v_idle nan, m_idle nan
# [12][20]: ene = nan, v_idle nan, m_idle nan
# [12][30]: ene = nan, v_idle nan, m_idle nan
# [12][40]: ene = nan, v_idle nan, m_idle nan
# [12][50]: ene = nan, v_idle nan, m_idle nan
# [12][60]: ene = nan, v_idle nan, m_idle nan
# [12][70]: ene = nan, v_idle nan, m_idle nan
# [12][80]: ene = nan, v_idle nan, m_idle nan
# [12][90]: ene = nan, v_idle nan, m_idle nan
# [12][100]: ene = nan, v_idle nan, m_idle nan
# [12][110]: ene = nan, v_idle nan, m_idle nan
# [12][120]: ene = nan, v_idle nan, m_idle nan
# [12][130]: ene = nan, v_idle nan, m_idle nan
# [12][140]: ene = nan, v_idle nan, m_idle nan
# [12][150]: ene = nan, v_idle nan, m_idle nan
# [12][160]: ene = nan, v_idle nan, m_idle nan
# [12][170]: ene = nan, v_idle nan, m_idle nan
# [12][180]: ene = nan, v_idle nan, m_idle nan
# [12][190]: ene = nan, v_idle nan, m_idle nan
# [12][200]: ene = nan, v_idle nan, m_idle nan
# [13][10]: ene = nan, v_idle nan, m_idle nan
# [13][20]: ene = nan, v_idle nan, m_idle nan
# [13][30]: ene = nan, v_idle nan, m_idle nan
# [13][40]: ene = nan, v_idle nan, m_idle nan
# [13][50]: ene = nan, v_idle nan, m_idle nan
# [13][60]: ene = nan, v_idle nan, m_idle nan
# [13][70]: ene = nan, v_idle nan, m_idle nan
# [13][80]: ene = nan, v_idle nan, m_idle nan
# [13][90]: ene = nan, v_idle nan, m_idle nan
# [13][100]: ene = nan, v_idle nan, m_idle nan
# [13][110]: ene = nan, v_idle nan, m_idle nan
# [13][120]: ene = nan, v_idle nan, m_idle nan
# [13][130]: ene = nan, v_idle nan, m_idle nan
# [13][140]: ene = nan, v_idle nan, m_idle nan
# [13][150]: ene = nan, v_idle nan, m_idle nan
# [13][160]: ene = nan, v_idle nan, m_idle nan
# [13][170]: ene = nan, v_idle nan, m_idle nan
# [13][180]: ene = nan, v_idle nan, m_idle nan
# [13][190]: ene = nan, v_idle nan, m_idle nan
# [13][200]: ene = nan, v_idle nan, m_idle nan
# [14][10]: ene = nan, v_idle nan, m_idle nan
# [14][20]: ene = nan, v_idle nan, m_idle nan
# [14][30]: ene = nan, v_idle nan, m_idle nan
# [14][40]: ene = nan, v_idle nan, m_idle nan
# [14][50]: ene = nan, v_idle nan, m_idle nan
# [14][60]: ene = nan, v_idle nan, m_idle nan
# [14][70]: ene = nan, v_idle nan, m_idle nan
# [14][80]: ene = nan, v_idle nan, m_idle nan
# [14][90]: ene = nan, v_idle nan, m_idle nan
# [14][100]: ene = nan, v_idle nan, m_idle nan
# [14][110]: ene = nan, v_idle nan, m_idle nan
# [14][120]: ene = nan, v_idle nan, m_idle nan
# [14][130]: ene = nan, v_idle nan, m_idle nan
# [14][140]: ene = nan, v_idle nan, m_idle nan
# [14][150]: ene = nan, v_idle nan, m_idle nan
# [14][160]: ene = nan, v_idle nan, m_idle nan
# [14][170]: ene = nan, v_idle nan, m_idle nan
# [14][180]: ene = nan, v_idle nan, m_idle nan
# [14][190]: ene = nan, v_idle nan, m_idle nan
# [14][200]: ene = nan, v_idle nan, m_idle nan
# [15][10]: ene = nan, v_idle nan, m_idle nan
# [15][20]: ene = nan, v_idle nan, m_idle nan
# [15][30]: ene = nan, v_idle nan, m_idle nan
# [15][40]: ene = nan, v_idle nan, m_idle nan
# [15][50]: ene = nan, v_idle nan, m_idle nan
# [15][60]: ene = nan, v_idle nan, m_idle nan
# [15][70]: ene = nan, v_idle nan, m_idle nan
# [15][80]: ene = nan, v_idle nan, m_idle nan
# [15][90]: ene = nan, v_idle nan, m_idle nan
# [15][100]: ene = nan, v_idle nan, m_idle nan
# [15][110]: ene = nan, v_idle nan, m_idle nan
# [15][120]: ene = nan, v_idle nan, m_idle nan
# [15][130]: ene = nan, v_idle nan, m_idle nan
# [15][140]: ene = nan, v_idle nan, m_idle nan
# [15][150]: ene = nan, v_idle nan, m_idle nan
# [15][160]: ene = nan, v_idle nan, m_idle nan
# [15][170]: ene = nan, v_idle nan, m_idle nan
# [15][180]: ene = nan, v_idle nan, m_idle nan
# [15][190]: ene = nan, v_idle nan, m_idle nan
# [15][200]: ene = nan, v_idle nan, m_idle nan
# [16][10]: ene = nan, v_idle nan, m_idle nan
# [16][20]: ene = nan, v_idle nan, m_idle nan
# [16][30]: ene = nan, v_idle nan, m_idle nan
# [16][40]: ene = nan, v_idle nan, m_idle nan
# [16][50]: ene = nan, v_idle nan, m_idle nan
# [16][60]: ene = nan, v_idle nan, m_idle nan
# [16][70]: ene = nan, v_idle nan, m_idle nan
# [16][80]: ene = nan, v_idle nan, m_idle nan
# [16][90]: ene = nan, v_idle nan, m_idle nan
# [16][100]: ene = nan, v_idle nan, m_idle nan
# [16][110]: ene = nan, v_idle nan, m_idle nan
# [16][120]: ene = nan, v_idle nan, m_idle nan
# [16][130]: ene = nan, v_idle nan, m_idle nan
# [16][140]: ene = nan, v_idle nan, m_idle nan
# [16][150]: ene = nan, v_idle nan, m_idle nan
# [16][160]: ene = nan, v_idle nan, m_idle nan
# [16][170]: ene = nan, v_idle nan, m_idle nan
# [16][180]: ene = nan, v_idle nan, m_idle nan
# [16][190]: ene = nan, v_idle nan, m_idle nan
# [16][200]: ene = nan, v_idle nan, m_idle nan
# [17][10]: ene = nan, v_idle nan, m_idle nan
# [17][20]: ene = nan, v_idle nan, m_idle nan
# [17][30]: ene = nan, v_idle nan, m_idle nan
# [17][40]: ene = nan, v_idle nan, m_idle nan
# [17][50]: ene = nan, v_idle nan, m_idle nan
# [17][60]: ene = nan, v_idle nan, m_idle nan
# [17][70]: ene = nan, v_idle nan, m_idle nan
# [17][80]: ene = nan, v_idle nan, m_idle nan
# [17][90]: ene = nan, v_idle nan, m_idle nan
# [17][100]: ene = nan, v_idle nan, m_idle nan
# [17][110]: ene = nan, v_idle nan, m_idle nan
# [17][120]: ene = nan, v_idle nan, m_idle nan
# [17][130]: ene = nan, v_idle nan, m_idle nan
# [17][140]: ene = nan, v_idle nan, m_idle nan
# [17][150]: ene = nan, v_idle nan, m_idle nan
# [17][160]: ene = nan, v_idle nan, m_idle nan
# [17][170]: ene = nan, v_idle nan, m_idle nan
# [17][180]: ene = nan, v_idle nan, m_idle nan
# [17][190]: ene = nan, v_idle nan, m_idle nan
# [17][200]: ene = nan, v_idle nan, m_idle nan
# [18][10]: ene = nan, v_idle nan, m_idle nan
# [18][20]: ene = nan, v_idle nan, m_idle nan
# [18][30]: ene = nan, v_idle nan, m_idle nan
# [18][40]: ene = nan, v_idle nan, m_idle nan
# [18][50]: ene = nan, v_idle nan, m_idle nan
# [18][60]: ene = nan, v_idle nan, m_idle nan
# [18][70]: ene = nan, v_idle nan, m_idle nan
# [18][80]: ene = nan, v_idle nan, m_idle nan
# [18][90]: ene = nan, v_idle nan, m_idle nan
# [18][100]: ene = nan, v_idle nan, m_idle nan
# [18][110]: ene = nan, v_idle nan, m_idle nan
# [18][120]: ene = nan, v_idle nan, m_idle nan
# [18][130]: ene = nan, v_idle nan, m_idle nan
# [18][140]: ene = nan, v_idle nan, m_idle nan
# [18][150]: ene = nan, v_idle nan, m_idle nan
# [18][160]: ene = nan, v_idle nan, m_idle nan
# [18][170]: ene = nan, v_idle nan, m_idle nan
# [18][180]: ene = nan, v_idle nan, m_idle nan
# [18][190]: ene = nan, v_idle nan, m_idle nan
# [18][200]: ene = nan, v_idle nan, m_idle nan
# [19][10]: ene = nan, v_idle nan, m_idle nan
# [19][20]: ene = nan, v_idle nan, m_idle nan
# [19][30]: ene = nan, v_idle nan, m_idle nan
# [19][40]: ene = nan, v_idle nan, m_idle nan
# [19][50]: ene = nan, v_idle nan, m_idle nan
# [19][60]: ene = nan, v_idle nan, m_idle nan
# [19][70]: ene = nan, v_idle nan, m_idle nan
# [19][80]: ene = nan, v_idle nan, m_idle nan
# [19][90]: ene = nan, v_idle nan, m_idle nan
# [19][100]: ene = nan, v_idle nan, m_idle nan
# [19][110]: ene = nan, v_idle nan, m_idle nan
# [19][120]: ene = nan, v_idle nan, m_idle nan
# [19][130]: ene = nan, v_idle nan, m_idle nan
# [19][140]: ene = nan, v_idle nan, m_idle nan
# [19][150]: ene = nan, v_idle nan, m_idle nan
# [19][160]: ene = nan, v_idle nan, m_idle nan
# [19][170]: ene = nan, v_idle nan, m_idle nan
# [19][180]: ene = nan, v_idle nan, m_idle nan
# [19][190]: ene = nan, v_idle nan, m_idle nan
# [19][200]: ene = nan, v_idle nan, m_idle nan
# [20][10]: ene = nan, v_idle nan, m_idle nan
# [20][20]: ene = nan, v_idle nan, m_idle nan
# [20][30]: ene = nan, v_idle nan, m_idle nan
# [20][40]: ene = nan, v_idle nan, m_idle nan
# [20][50]: ene = nan, v_idle nan, m_idle nan
# [20][60]: ene = nan, v_idle nan, m_idle nan
# [20][70]: ene = nan, v_idle nan, m_idle nan
# [20][80]: ene = nan, v_idle nan, m_idle nan
# [20][90]: ene = nan, v_idle nan, m_idle nan
# [20][100]: ene = nan, v_idle nan, m_idle nan
# [20][110]: ene = nan, v_idle nan, m_idle nan
# [20][120]: ene = nan, v_idle nan, m_idle nan
# [20][130]: ene = nan, v_idle nan, m_idle nan
# [20][140]: ene = nan, v_idle nan, m_idle nan
# [20][150]: ene = nan, v_idle nan, m_idle nan
# [20][160]: ene = nan, v_idle nan, m_idle nan
# [20][170]: ene = nan, v_idle nan, m_idle nan
# [20][180]: ene = nan, v_idle nan, m_idle nan
# [20][190]: ene = nan, v_idle nan, m_idle nan
# [20][200]: ene = nan, v_idle nan, m_idle nan
# [21][10]: ene = nan, v_idle nan, m_idle nan
# [21][20]: ene = nan, v_idle nan, m_idle nan
# [21][30]: ene = nan, v_idle nan, m_idle nan
# [21][40]: ene = nan, v_idle nan, m_idle nan
# [21][50]: ene = nan, v_idle nan, m_idle nan
# [21][60]: ene = nan, v_idle nan, m_idle nan
# [21][70]: ene = nan, v_idle nan, m_idle nan
# [21][80]: ene = nan, v_idle nan, m_idle nan
# [21][90]: ene = nan, v_idle nan, m_idle nan
# [21][100]: ene = nan, v_idle nan, m_idle nan
# [21][110]: ene = nan, v_idle nan, m_idle nan
# [21][120]: ene = nan, v_idle nan, m_idle nan
# [21][130]: ene = nan, v_idle nan, m_idle nan
# [21][140]: ene = nan, v_idle nan, m_idle nan
# [21][150]: ene = nan, v_idle nan, m_idle nan
# [21][160]: ene = nan, v_idle nan, m_idle nan
# [21][170]: ene = nan, v_idle nan, m_idle nan
# [21][180]: ene = nan, v_idle nan, m_idle nan
# [21][190]: ene = nan, v_idle nan, m_idle nan
# [21][200]: ene = nan, v_idle nan, m_idle nan
# [22][10]: ene = nan, v_idle nan, m_idle nan
# [22][20]: ene = nan, v_idle nan, m_idle nan
# [22][30]: ene = nan, v_idle nan, m_idle nan
# [22][40]: ene = nan, v_idle nan, m_idle nan
# [22][50]: ene = nan, v_idle nan, m_idle nan
# [22][60]: ene = nan, v_idle nan, m_idle nan
# [22][70]: ene = nan, v_idle nan, m_idle nan
# [22][80]: ene = nan, v_idle nan, m_idle nan
# [22][90]: ene = nan, v_idle nan, m_idle nan
# [22][100]: ene = nan, v_idle nan, m_idle nan
# [22][110]: ene = nan, v_idle nan, m_idle nan
# [22][120]: ene = nan, v_idle nan, m_idle nan
# [22][130]: ene = nan, v_idle nan, m_idle nan
# [22][140]: ene = nan, v_idle nan, m_idle nan
# [22][150]: ene = nan, v_idle nan, m_idle nan
# [22][160]: ene = nan, v_idle nan, m_idle nan
# [22][170]: ene = nan, v_idle nan, m_idle nan
# [22][180]: ene = nan, v_idle nan, m_idle nan
# [22][190]: ene = nan, v_idle nan, m_idle nan
# [22][200]: ene = nan, v_idle nan, m_idle nan
# [23][10]: ene = nan, v_idle nan, m_idle nan
# [23][20]: ene = nan, v_idle nan, m_idle nan
# [23][30]: ene = nan, v_idle nan, m_idle nan
# [23][40]: ene = nan, v_idle nan, m_idle nan
# [23][50]: ene = nan, v_idle nan, m_idle nan
# [23][60]: ene = nan, v_idle nan, m_idle nan
# [23][70]: ene = nan, v_idle nan, m_idle nan
# [23][80]: ene = nan, v_idle nan, m_idle nan
# [23][90]: ene = nan, v_idle nan, m_idle nan
# [23][100]: ene = nan, v_idle nan, m_idle nan
# [23][110]: ene = nan, v_idle nan, m_idle nan
# [23][120]: ene = nan, v_idle nan, m_idle nan
# [23][130]: ene = nan, v_idle nan, m_idle nan
# [23][140]: ene = nan, v_idle nan, m_idle nan
# [23][150]: ene = nan, v_idle nan, m_idle nan
# [23][160]: ene = nan, v_idle nan, m_idle nan
# [23][170]: ene = nan, v_idle nan, m_idle nan
# [23][180]: ene = nan, v_idle nan, m_idle nan
# [23][190]: ene = nan, v_idle nan, m_idle nan
# [23][200]: ene = nan, v_idle nan, m_idle nan
# [24][10]: ene = nan, v_idle nan, m_idle nan
# [24][20]: ene = nan, v_idle nan, m_idle nan
# [24][30]: ene = nan, v_idle nan, m_idle nan
# [24][40]: ene = nan, v_idle nan, m_idle nan
# [24][50]: ene = nan, v_idle nan, m_idle nan
# [24][60]: ene = nan, v_idle nan, m_idle nan
# [24][70]: ene = nan, v_idle nan, m_idle nan
# [24][80]: ene = nan, v_idle nan, m_idle nan
# [24][90]: ene = nan, v_idle nan, m_idle nan
# [24][100]: ene = nan, v_idle nan, m_idle nan
# [24][110]: ene = nan, v_idle nan, m_idle nan
# [24][120]: ene = nan, v_idle nan, m_idle nan
# [24][130]: ene = nan, v_idle nan, m_idle nan
# [24][140]: ene = nan, v_idle nan, m_idle nan
# [24][150]: ene = nan, v_idle nan, m_idle nan
# [24][160]: ene = nan, v_idle nan, m_idle nan
# [24][170]: ene = nan, v_idle nan, m_idle nan
# [24][180]: ene = nan, v_idle nan, m_idle nan
# [24][190]: ene = nan, v_idle nan, m_idle nan
# [24][200]: ene = nan, v_idle nan, m_idle nan
# [25][10]: ene = nan, v_idle nan, m_idle nan
# [25][20]: ene = nan, v_idle nan, m_idle nan
# [25][30]: ene = nan, v_idle nan, m_idle nan
# [25][40]: ene = nan, v_idle nan, m_idle nan
# [25][50]: ene = nan, v_idle nan, m_idle nan
# [25][60]: ene = nan, v_idle nan, m_idle nan
# [25][70]: ene = nan, v_idle nan, m_idle nan
# [25][80]: ene = nan, v_idle nan, m_idle nan
# [25][90]: ene = nan, v_idle nan, m_idle nan
# [25][100]: ene = nan, v_idle nan, m_idle nan
# [25][110]: ene = nan, v_idle nan, m_idle nan
# [25][120]: ene = nan, v_idle nan, m_idle nan
# [25][130]: ene = nan, v_idle nan, m_idle nan
# [25][140]: ene = nan, v_idle nan, m_idle nan
# [25][150]: ene = nan, v_idle nan, m_idle nan
# [25][160]: ene = nan, v_idle nan, m_idle nan
# [25][170]: ene = nan, v_idle nan, m_idle nan
# [25][180]: ene = nan, v_idle nan, m_idle nan
# [25][190]: ene = nan, v_idle nan, m_idle nan
# [25][200]: ene = nan, v_idle nan, m_idle nan
# [26][10]: ene = nan, v_idle nan, m_idle nan
# [26][20]: ene = nan, v_idle nan, m_idle nan
# [26][30]: ene = nan, v_idle nan, m_idle nan
# [26][40]: ene = nan, v_idle nan, m_idle nan
# [26][50]: ene = nan, v_idle nan, m_idle nan
# [26][60]: ene = nan, v_idle nan, m_idle nan
# [26][70]: ene = nan, v_idle nan, m_idle nan
# [26][80]: ene = nan, v_idle nan, m_idle nan
# [26][90]: ene = nan, v_idle nan, m_idle nan
# [26][100]: ene = nan, v_idle nan, m_idle nan
# [26][110]: ene = nan, v_idle nan, m_idle nan
# [26][120]: ene = nan, v_idle nan, m_idle nan
# [26][130]: ene = nan, v_idle nan, m_idle nan
# [26][140]: ene = nan, v_idle nan, m_idle nan
# [26][150]: ene = nan, v_idle nan, m_idle nan
# [26][160]: ene = nan, v_idle nan, m_idle nan
# [26][170]: ene = nan, v_idle nan, m_idle nan
# [26][180]: ene = nan, v_idle nan, m_idle nan
# [26][190]: ene = nan, v_idle nan, m_idle nan
# [26][200]: ene = nan, v_idle nan, m_idle nan
# [27][10]: ene = nan, v_idle nan, m_idle nan
# [27][20]: ene = nan, v_idle nan, m_idle nan
# [27][30]: ene = nan, v_idle nan, m_idle nan
# [27][40]: ene = nan, v_idle nan, m_idle nan
# [27][50]: ene = nan, v_idle nan, m_idle nan
# [27][60]: ene = nan, v_idle nan, m_idle nan
# [27][70]: ene = nan, v_idle nan, m_idle nan
# [27][80]: ene = nan, v_idle nan, m_idle nan
# [27][90]: ene = nan, v_idle nan, m_idle nan
# [27][100]: ene = nan, v_idle nan, m_idle nan
# [27][110]: ene = nan, v_idle nan, m_idle nan
# [27][120]: ene = nan, v_idle nan, m_idle nan
# [27][130]: ene = nan, v_idle nan, m_idle nan
# [27][140]: ene = nan, v_idle nan, m_idle nan
# [27][150]: ene = nan, v_idle nan, m_idle nan
# [27][160]: ene = nan, v_idle nan, m_idle nan
# [27][170]: ene = nan, v_idle nan, m_idle nan
# [27][180]: ene = nan, v_idle nan, m_idle nan
# [27][190]: ene = nan, v_idle nan, m_idle nan
# [27][200]: ene = nan, v_idle nan, m_idle nan
# [28][10]: ene = nan, v_idle nan, m_idle nan
# [28][20]: ene = nan, v_idle nan, m_idle nan
# [28][30]: ene = nan, v_idle nan, m_idle nan
# [28][40]: ene = nan, v_idle nan, m_idle nan
# [28][50]: ene = nan, v_idle nan, m_idle nan
# [28][60]: ene = nan, v_idle nan, m_idle nan
# [28][70]: ene = nan, v_idle nan, m_idle nan
# [28][80]: ene = nan, v_idle nan, m_idle nan
# [28][90]: ene = nan, v_idle nan, m_idle nan
# [28][100]: ene = nan, v_idle nan, m_idle nan
# [28][110]: ene = nan, v_idle nan, m_idle nan
# [28][120]: ene = nan, v_idle nan, m_idle nan
# [28][130]: ene = nan, v_idle nan, m_idle nan
# [28][140]: ene = nan, v_idle nan, m_idle nan
# [28][150]: ene = nan, v_idle nan, m_idle nan
# [28][160]: ene = nan, v_idle nan, m_idle nan
# [28][170]: ene = nan, v_idle nan, m_idle nan
# [28][180]: ene = nan, v_idle nan, m_idle nan
# [28][190]: ene = nan, v_idle nan, m_idle nan
# [28][200]: ene = nan, v_idle nan, m_idle nan
# [29][10]: ene = nan, v_idle nan, m_idle nan
# [29][20]: ene = nan, v_idle nan, m_idle nan
# [29][30]: ene = nan, v_idle nan, m_idle nan
# [29][40]: ene = nan, v_idle nan, m_idle nan
# [29][50]: ene = nan, v_idle nan, m_idle nan
# [29][60]: ene = nan, v_idle nan, m_idle nan
# [29][70]: ene = nan, v_idle nan, m_idle nan
# [29][80]: ene = nan, v_idle nan, m_idle nan
# [29][90]: ene = nan, v_idle nan, m_idle nan
# [29][100]: ene = nan, v_idle nan, m_idle nan
# [29][110]: ene = nan, v_idle nan, m_idle nan
# [29][120]: ene = nan, v_idle nan, m_idle nan
# [29][130]: ene = nan, v_idle nan, m_idle nan
# [29][140]: ene = nan, v_idle nan, m_idle nan
# [29][150]: ene = nan, v_idle nan, m_idle nan
# [29][160]: ene = nan, v_idle nan, m_idle nan
# [29][170]: ene = nan, v_idle nan, m_idle nan
# [29][180]: ene = nan, v_idle nan, m_idle nan
# [29][190]: ene = nan, v_idle nan, m_idle nan
# [29][200]: ene = nan, v_idle nan, m_idle nan
# [30][10]: ene = nan, v_idle nan, m_idle nan
# [30][20]: ene = nan, v_idle nan, m_idle nan
# [30][30]: ene = nan, v_idle nan, m_idle nan
# [30][40]: ene = nan, v_idle nan, m_idle nan
# [30][50]: ene = nan, v_idle nan, m_idle nan
# [30][60]: ene = nan, v_idle nan, m_idle nan
# [30][70]: ene = nan, v_idle nan, m_idle nan
# [30][80]: ene = nan, v_idle nan, m_idle nan
# [30][90]: ene = nan, v_idle nan, m_idle nan
# [30][100]: ene = nan, v_idle nan, m_idle nan
# [30][110]: ene = nan, v_idle nan, m_idle nan
# [30][120]: ene = nan, v_idle nan, m_idle nan
# [30][130]: ene = nan, v_idle nan, m_idle nan
# [30][140]: ene = nan, v_idle nan, m_idle nan
# [30][150]: ene = nan, v_idle nan, m_idle nan
# [30][160]: ene = nan, v_idle nan, m_idle nan
# [30][170]: ene = nan, v_idle nan, m_idle nan
# [30][180]: ene = nan, v_idle nan, m_idle nan
# [30][190]: ene = nan, v_idle nan, m_idle nan
# [30][200]: ene = nan, v_idle nan, m_idle nan
# [31][10]: ene = nan, v_idle nan, m_idle nan
# [31][20]: ene = nan, v_idle nan, m_idle nan
# [31][30]: ene = nan, v_idle nan, m_idle nan
# [31][40]: ene = nan, v_idle nan, m_idle nan
# [31][50]: ene = nan, v_idle nan, m_idle nan
# [31][60]: ene = nan, v_idle nan, m_idle nan
# [31][70]: ene = nan, v_idle nan, m_idle nan
# [31][80]: ene = nan, v_idle nan, m_idle nan
# [31][90]: ene = nan, v_idle nan, m_idle nan
# [31][100]: ene = nan, v_idle nan, m_idle nan
# [31][110]: ene = nan, v_idle nan, m_idle nan
# [31][120]: ene = nan, v_idle nan, m_idle nan
# [31][130]: ene = nan, v_idle nan, m_idle nan
# [31][140]: ene = nan, v_idle nan, m_idle nan
# [31][150]: ene = nan, v_idle nan, m_idle nan
# [31][160]: ene = nan, v_idle nan, m_idle nan
# [31][170]: ene = nan, v_idle nan, m_idle nan
# [31][180]: ene = nan, v_idle nan, m_idle nan
# [31][190]: ene = nan, v_idle nan, m_idle nan
# [31][200]: ene = nan, v_idle nan, m_idle nan
# [32][10]: ene = nan, v_idle nan, m_idle nan
# [32][20]: ene = nan, v_idle nan, m_idle nan
# [32][30]: ene = nan, v_idle nan, m_idle nan
# [32][40]: ene = nan, v_idle nan, m_idle nan
# [32][50]: ene = nan, v_idle nan, m_idle nan
# [32][60]: ene = nan, v_idle nan, m_idle nan
# [32][70]: ene = nan, v_idle nan, m_idle nan
# [32][80]: ene = nan, v_idle nan, m_idle nan
# [32][90]: ene = nan, v_idle nan, m_idle nan
# [32][100]: ene = nan, v_idle nan, m_idle nan
# [32][110]: ene = nan, v_idle nan, m_idle nan
# [32][120]: ene = nan, v_idle nan, m_idle nan
# [32][130]: ene = nan, v_idle nan, m_idle nan
# [32][140]: ene = nan, v_idle nan, m_idle nan
# [32][150]: ene = nan, v_idle nan, m_idle nan
# [32][160]: ene = nan, v_idle nan, m_idle nan
# [32][170]: ene = nan, v_idle nan, m_idle nan
# [32][180]: ene = nan, v_idle nan, m_idle nan
# [32][190]: ene = nan, v_idle nan, m_idle nan
# [32][200]: ene = nan, v_idle nan, m_idle nan
# [33][10]: ene = nan, v_idle nan, m_idle nan
# [33][20]: ene = nan, v_idle nan, m_idle nan
# [33][30]: ene = nan, v_idle nan, m_idle nan
# [33][40]: ene = nan, v_idle nan, m_idle nan
# [33][50]: ene = nan, v_idle nan, m_idle nan
# [33][60]: ene = nan, v_idle nan, m_idle nan
# [33][70]: ene = nan, v_idle nan, m_idle nan
# [33][80]: ene = nan, v_idle nan, m_idle nan
# [33][90]: ene = nan, v_idle nan, m_idle nan
# [33][100]: ene = nan, v_idle nan, m_idle nan
# [33][110]: ene = nan, v_idle nan, m_idle nan
# [33][120]: ene = nan, v_idle nan, m_idle nan
# [33][130]: ene = nan, v_idle nan, m_idle nan
# [33][140]: ene = nan, v_idle nan, m_idle nan
# [33][150]: ene = nan, v_idle nan, m_idle nan
# [33][160]: ene = nan, v_idle nan, m_idle nan
# [33][170]: ene = nan, v_idle nan, m_idle nan
# [33][180]: ene = nan, v_idle nan, m_idle nan
# [33][190]: ene = nan, v_idle nan, m_idle nan
# [33][200]: ene = nan, v_idle nan, m_idle nan
# [34][10]: ene = nan, v_idle nan, m_idle nan
# [34][20]: ene = nan, v_idle nan, m_idle nan
# [34][30]: ene = nan, v_idle nan, m_idle nan
# [34][40]: ene = nan, v_idle nan, m_idle nan
# [34][50]: ene = nan, v_idle nan, m_idle nan
# [34][60]: ene = nan, v_idle nan, m_idle nan
# [34][70]: ene = nan, v_idle nan, m_idle nan
# [34][80]: ene = nan, v_idle nan, m_idle nan
# [34][90]: ene = nan, v_idle nan, m_idle nan
# [34][100]: ene = nan, v_idle nan, m_idle nan
# [34][110]: ene = nan, v_idle nan, m_idle nan
# [34][120]: ene = nan, v_idle nan, m_idle nan
# [34][130]: ene = nan, v_idle nan, m_idle nan
# [34][140]: ene = nan, v_idle nan, m_idle nan
# [34][150]: ene = nan, v_idle nan, m_idle nan
# [34][160]: ene = nan, v_idle nan, m_idle nan
# [34][170]: ene = nan, v_idle nan, m_idle nan
# [34][180]: ene = nan, v_idle nan, m_idle nan
# [34][190]: ene = nan, v_idle nan, m_idle nan
# [34][200]: ene = nan, v_idle nan, m_idle nan
# [35][10]: ene = nan, v_idle nan, m_idle nan
# [35][20]: ene = nan, v_idle nan, m_idle nan
# [35][30]: ene = nan, v_idle nan, m_idle nan
# [35][40]: ene = nan, v_idle nan, m_idle nan
# [35][50]: ene = nan, v_idle nan, m_idle nan
# [35][60]: ene = nan, v_idle nan, m_idle nan
# [35][70]: ene = nan, v_idle nan, m_idle nan
# [35][80]: ene = nan, v_idle nan, m_idle nan
# [35][90]: ene = nan, v_idle nan, m_idle nan
# [35][100]: ene = nan, v_idle nan, m_idle nan
# [35][110]: ene = nan, v_idle nan, m_idle nan
# [35][120]: ene = nan, v_idle nan, m_idle nan
# [35][130]: ene = nan, v_idle nan, m_idle nan
# [35][140]: ene = nan, v_idle nan, m_idle nan
# [35][150]: ene = nan, v_idle nan, m_idle nan
# [35][160]: ene = nan, v_idle nan, m_idle nan
# [35][170]: ene = nan, v_idle nan, m_idle nan
# [35][180]: ene = nan, v_idle nan, m_idle nan
# [35][190]: ene = nan, v_idle nan, m_idle nan
# [35][200]: ene = nan, v_idle nan, m_idle nan
# [36][10]: ene = nan, v_idle nan, m_idle nan
# [36][20]: ene = nan, v_idle nan, m_idle nan
# [36][30]: ene = nan, v_idle nan, m_idle nan
# [36][40]: ene = nan, v_idle nan, m_idle nan
# [36][50]: ene = nan, v_idle nan, m_idle nan
# [36][60]: ene = nan, v_idle nan, m_idle nan
# [36][70]: ene = nan, v_idle nan, m_idle nan
# [36][80]: ene = nan, v_idle nan, m_idle nan
# [36][90]: ene = nan, v_idle nan, m_idle nan
# [36][100]: ene = nan, v_idle nan, m_idle nan
# [36][110]: ene = nan, v_idle nan, m_idle nan
# [36][120]: ene = nan, v_idle nan, m_idle nan
# [36][130]: ene = nan, v_idle nan, m_idle nan
# [36][140]: ene = nan, v_idle nan, m_idle nan
# [36][150]: ene = nan, v_idle nan, m_idle nan
# [36][160]: ene = nan, v_idle nan, m_idle nan
# [36][170]: ene = nan, v_idle nan, m_idle nan
# [36][180]: ene = nan, v_idle nan, m_idle nan
# [36][190]: ene = nan, v_idle nan, m_idle nan
# [36][200]: ene = nan, v_idle nan, m_idle nan
# [37][10]: ene = nan, v_idle nan, m_idle nan
# [37][20]: ene = nan, v_idle nan, m_idle nan
# [37][30]: ene = nan, v_idle nan, m_idle nan
# [37][40]: ene = nan, v_idle nan, m_idle nan
# [37][50]: ene = nan, v_idle nan, m_idle nan
# [37][60]: ene = nan, v_idle nan, m_idle nan
# [37][70]: ene = nan, v_idle nan, m_idle nan
# [37][80]: ene = nan, v_idle nan, m_idle nan
# [37][90]: ene = nan, v_idle nan, m_idle nan
# [37][100]: ene = nan, v_idle nan, m_idle nan
# [37][110]: ene = nan, v_idle nan, m_idle nan
# [37][120]: ene = nan, v_idle nan, m_idle nan
# [37][130]: ene = nan, v_idle nan, m_idle nan
# [37][140]: ene = nan, v_idle nan, m_idle nan
# [37][150]: ene = nan, v_idle nan, m_idle nan
# [37][160]: ene = nan, v_idle nan, m_idle nan
# [37][170]: ene = nan, v_idle nan, m_idle nan
# [37][180]: ene = nan, v_idle nan, m_idle nan
# [37][190]: ene = nan, v_idle nan, m_idle nan
# [37][200]: ene = nan, v_idle nan, m_idle nan
# [38][10]: ene = nan, v_idle nan, m_idle nan
# [38][20]: ene = nan, v_idle nan, m_idle nan
# [38][30]: ene = nan, v_idle nan, m_idle nan
# [38][40]: ene = nan, v_idle nan, m_idle nan
# [38][50]: ene = nan, v_idle nan, m_idle nan
# [38][60]: ene = nan, v_idle nan, m_idle nan
# [38][70]: ene = nan, v_idle nan, m_idle nan
# [38][80]: ene = nan, v_idle nan, m_idle nan
# [38][90]: ene = nan, v_idle nan, m_idle nan
# [38][100]: ene = nan, v_idle nan, m_idle nan
# [38][110]: ene = nan, v_idle nan, m_idle nan
# [38][120]: ene = nan, v_idle nan, m_idle nan
# [38][130]: ene = nan, v_idle nan, m_idle nan
# [38][140]: ene = nan, v_idle nan, m_idle nan
# [38][150]: ene = nan, v_idle nan, m_idle nan
# [38][160]: ene = nan, v_idle nan, m_idle nan
# [38][170]: ene = nan, v_idle nan, m_idle nan
# [38][180]: ene = nan, v_idle nan, m_idle nan
# [38][190]: ene = nan, v_idle nan, m_idle nan
# [38][200]: ene = nan, v_idle nan, m_idle nan
# [39][10]: ene = nan, v_idle nan, m_idle nan
# [39][20]: ene = nan, v_idle nan, m_idle nan
# [39][30]: ene = nan, v_idle nan, m_idle nan
# [39][40]: ene = nan, v_idle nan, m_idle nan
# [39][50]: ene = nan, v_idle nan, m_idle nan
# [39][60]: ene = nan, v_idle nan, m_idle nan
# [39][70]: ene = nan, v_idle nan, m_idle nan
# [39][80]: ene = nan, v_idle nan, m_idle nan
# [39][90]: ene = nan, v_idle nan, m_idle nan
# [39][100]: ene = nan, v_idle nan, m_idle nan
# [39][110]: ene = nan, v_idle nan, m_idle nan
# [39][120]: ene = nan, v_idle nan, m_idle nan
# [39][130]: ene = nan, v_idle nan, m_idle nan
# [39][140]: ene = nan, v_idle nan, m_idle nan
# [39][150]: ene = nan, v_idle nan, m_idle nan
# [39][160]: ene = nan, v_idle nan, m_idle nan
# [39][170]: ene = nan, v_idle nan, m_idle nan
# [39][180]: ene = nan, v_idle nan, m_idle nan
# [39][190]: ene = nan, v_idle nan, m_idle nan
# [39][200]: ene = nan, v_idle nan, m_idle nan
# [40][10]: ene = nan, v_idle nan, m_idle nan
# [40][20]: ene = nan, v_idle nan, m_idle nan
# [40][30]: ene = nan, v_idle nan, m_idle nan
# [40][40]: ene = nan, v_idle nan, m_idle nan
# [40][50]: ene = nan, v_idle nan, m_idle nan
# [40][60]: ene = nan, v_idle nan, m_idle nan
# [40][70]: ene = nan, v_idle nan, m_idle nan
# [40][80]: ene = nan, v_idle nan, m_idle nan
# [40][90]: ene = nan, v_idle nan, m_idle nan
# [40][100]: ene = nan, v_idle nan, m_idle nan
# [40][110]: ene = nan, v_idle nan, m_idle nan
# [40][120]: ene = nan, v_idle nan, m_idle nan
# [40][130]: ene = nan, v_idle nan, m_idle nan
# [40][140]: ene = nan, v_idle nan, m_idle nan
# [40][150]: ene = nan, v_idle nan, m_idle nan
# [40][160]: ene = nan, v_idle nan, m_idle nan
# [40][170]: ene = nan, v_idle nan, m_idle nan
# [40][180]: ene = nan, v_idle nan, m_idle nan
# [40][190]: ene = nan, v_idle nan, m_idle nan
# [40][200]: ene = nan, v_idle nan, m_idle nan
# [41][10]: ene = nan, v_idle nan, m_idle nan
# [41][20]: ene = nan, v_idle nan, m_idle nan
# [41][30]: ene = nan, v_idle nan, m_idle nan
# [41][40]: ene = nan, v_idle nan, m_idle nan
# [41][50]: ene = nan, v_idle nan, m_idle nan
# [41][60]: ene = nan, v_idle nan, m_idle nan
# [41][70]: ene = nan, v_idle nan, m_idle nan
# [41][80]: ene = nan, v_idle nan, m_idle nan
# [41][90]: ene = nan, v_idle nan, m_idle nan
# [41][100]: ene = nan, v_idle nan, m_idle nan
# [41][110]: ene = nan, v_idle nan, m_idle nan
# [41][120]: ene = nan, v_idle nan, m_idle nan
# [41][130]: ene = nan, v_idle nan, m_idle nan
# [41][140]: ene = nan, v_idle nan, m_idle nan
# [41][150]: ene = nan, v_idle nan, m_idle nan
# [41][160]: ene = nan, v_idle nan, m_idle nan
# [41][170]: ene = nan, v_idle nan, m_idle nan
# [41][180]: ene = nan, v_idle nan, m_idle nan
# [41][190]: ene = nan, v_idle nan, m_idle nan
# [41][200]: ene = nan, v_idle nan, m_idle nan
# [42][10]: ene = nan, v_idle nan, m_idle nan
# [42][20]: ene = nan, v_idle nan, m_idle nan
# [42][30]: ene = nan, v_idle nan, m_idle nan
# [42][40]: ene = nan, v_idle nan, m_idle nan
# [42][50]: ene = nan, v_idle nan, m_idle nan
# [42][60]: ene = nan, v_idle nan, m_idle nan
# [42][70]: ene = nan, v_idle nan, m_idle nan
# [42][80]: ene = nan, v_idle nan, m_idle nan
# [42][90]: ene = nan, v_idle nan, m_idle nan
# [42][100]: ene = nan, v_idle nan, m_idle nan
# [42][110]: ene = nan, v_idle nan, m_idle nan
# [42][120]: ene = nan, v_idle nan, m_idle nan
# [42][130]: ene = nan, v_idle nan, m_idle nan
# [42][140]: ene = nan, v_idle nan, m_idle nan
# [42][150]: ene = nan, v_idle nan, m_idle nan
# [42][160]: ene = nan, v_idle nan, m_idle nan
# [42][170]: ene = nan, v_idle nan, m_idle nan
# [42][180]: ene = nan, v_idle nan, m_idle nan
# [42][190]: ene = nan, v_idle nan, m_idle nan
# [42][200]: ene = nan, v_idle nan, m_idle nan
# [43][10]: ene = nan, v_idle nan, m_idle nan
# [43][20]: ene = nan, v_idle nan, m_idle nan
# [43][30]: ene = nan, v_idle nan, m_idle nan
# [43][40]: ene = nan, v_idle nan, m_idle nan
# [43][50]: ene = nan, v_idle nan, m_idle nan
# [43][60]: ene = nan, v_idle nan, m_idle nan
# [43][70]: ene = nan, v_idle nan, m_idle nan
# [43][80]: ene = nan, v_idle nan, m_idle nan
# [43][90]: ene = nan, v_idle nan, m_idle nan
# [43][100]: ene = nan, v_idle nan, m_idle nan
# [43][110]: ene = nan, v_idle nan, m_idle nan
# [43][120]: ene = nan, v_idle nan, m_idle nan
# [43][130]: ene = nan, v_idle nan, m_idle nan
# [43][140]: ene = nan, v_idle nan, m_idle nan
# [43][150]: ene = nan, v_idle nan, m_idle nan
# [43][160]: ene = nan, v_idle nan, m_idle nan
# [43][170]: ene = nan, v_idle nan, m_idle nan
# [43][180]: ene = nan, v_idle nan, m_idle nan
# [43][190]: ene = nan, v_idle nan, m_idle nan
# [43][200]: ene = nan, v_idle nan, m_idle nan
# [44][10]: ene = nan, v_idle nan, m_idle nan
# [44][20]: ene = nan, v_idle nan, m_idle nan
# [44][30]: ene = nan, v_idle nan, m_idle nan
# [44][40]: ene = nan, v_idle nan, m_idle nan
# [44][50]: ene = nan, v_idle nan, m_idle nan
# [44][60]: ene = nan, v_idle nan, m_idle nan
# [44][70]: ene = nan, v_idle nan, m_idle nan
# [44][80]: ene = nan, v_idle nan, m_idle nan
# [44][90]: ene = nan, v_idle nan, m_idle nan
# [44][100]: ene = nan, v_idle nan, m_idle nan
# [44][110]: ene = nan, v_idle nan, m_idle nan
# [44][120]: ene = nan, v_idle nan, m_idle nan
# [44][130]: ene = nan, v_idle nan, m_idle nan
# [44][140]: ene = nan, v_idle nan, m_idle nan
# [44][150]: ene = nan, v_idle nan, m_idle nan
# [44][160]: ene = nan, v_idle nan, m_idle nan
# [44][170]: ene = nan, v_idle nan, m_idle nan
# [44][180]: ene = nan, v_idle nan, m_idle nan
# [44][190]: ene = nan, v_idle nan, m_idle nan
# [44][200]: ene = nan, v_idle nan, m_idle nan
# [45][10]: ene = nan, v_idle nan, m_idle nan
# [45][20]: ene = nan, v_idle nan, m_idle nan
# [45][30]: ene = nan, v_idle nan, m_idle nan
# [45][40]: ene = nan, v_idle nan, m_idle nan
# [45][50]: ene = nan, v_idle nan, m_idle nan
# [45][60]: ene = nan, v_idle nan, m_idle nan
# [45][70]: ene = nan, v_idle nan, m_idle nan
# [45][80]: ene = nan, v_idle nan, m_idle nan
# [45][90]: ene = nan, v_idle nan, m_idle nan
# [45][100]: ene = nan, v_idle nan, m_idle nan
# [45][110]: ene = nan, v_idle nan, m_idle nan
# [45][120]: ene = nan, v_idle nan, m_idle nan
# [45][130]: ene = nan, v_idle nan, m_idle nan
# [45][140]: ene = nan, v_idle nan, m_idle nan
# [45][150]: ene = nan, v_idle nan, m_idle nan
# [45][160]: ene = nan, v_idle nan, m_idle nan
# [45][170]: ene = nan, v_idle nan, m_idle nan
# [45][180]: ene = nan, v_idle nan, m_idle nan
# [45][190]: ene = nan, v_idle nan, m_idle nan
# [45][200]: ene = nan, v_idle nan, m_idle nan
# [46][10]: ene = nan, v_idle nan, m_idle nan
# [46][20]: ene = nan, v_idle nan, m_idle nan
# [46][30]: ene = nan, v_idle nan, m_idle nan
# [46][40]: ene = nan, v_idle nan, m_idle nan
# [46][50]: ene = nan, v_idle nan, m_idle nan
# [46][60]: ene = nan, v_idle nan, m_idle nan
# [46][70]: ene = nan, v_idle nan, m_idle nan
# [46][80]: ene = nan, v_idle nan, m_idle nan
# [46][90]: ene = nan, v_idle nan, m_idle nan
# [46][100]: ene = nan, v_idle nan, m_idle nan
# [46][110]: ene = nan, v_idle nan, m_idle nan
# [46][120]: ene = nan, v_idle nan, m_idle nan
# [46][130]: ene = nan, v_idle nan, m_idle nan
# [46][140]: ene = nan, v_idle nan, m_idle nan
# [46][150]: ene = nan, v_idle nan, m_idle nan
# [46][160]: ene = nan, v_idle nan, m_idle nan
# [46][170]: ene = nan, v_idle nan, m_idle nan
# [46][180]: ene = nan, v_idle nan, m_idle nan
# [46][190]: ene = nan, v_idle nan, m_idle nan
# [46][200]: ene = nan, v_idle nan, m_idle nan
# [47][10]: ene = nan, v_idle nan, m_idle nan
# [47][20]: ene = nan, v_idle nan, m_idle nan
# [47][30]: ene = nan, v_idle nan, m_idle nan
# [47][40]: ene = nan, v_idle nan, m_idle nan
# [47][50]: ene = nan, v_idle nan, m_idle nan
# [47][60]: ene = nan, v_idle nan, m_idle nan
# [47][70]: ene = nan, v_idle nan, m_idle nan
# [47][80]: ene = nan, v_idle nan, m_idle nan
# [47][90]: ene = nan, v_idle nan, m_idle nan
# [47][100]: ene = nan, v_idle nan, m_idle nan
# [47][110]: ene = nan, v_idle nan, m_idle nan
# [47][120]: ene = nan, v_idle nan, m_idle nan
# [47][130]: ene = nan, v_idle nan, m_idle nan
# [47][140]: ene = nan, v_idle nan, m_idle nan
# [47][150]: ene = nan, v_idle nan, m_idle nan
# [47][160]: ene = nan, v_idle nan, m_idle nan
# [47][170]: ene = nan, v_idle nan, m_idle nan
# [47][180]: ene = nan, v_idle nan, m_idle nan
# [47][190]: ene = nan, v_idle nan, m_idle nan
# [47][200]: ene = nan, v_idle nan, m_idle nan
# [48][10]: ene = nan, v_idle nan, m_idle nan
# [48][20]: ene = nan, v_idle nan, m_idle nan
# [48][30]: ene = nan, v_idle nan, m_idle nan
# [48][40]: ene = nan, v_idle nan, m_idle nan
# [48][50]: ene = nan, v_idle nan, m_idle nan
# [48][60]: ene = nan, v_idle nan, m_idle nan
# [48][70]: ene = nan, v_idle nan, m_idle nan
# [48][80]: ene = nan, v_idle nan, m_idle nan
# [48][90]: ene = nan, v_idle nan, m_idle nan
# [48][100]: ene = nan, v_idle nan, m_idle nan
# [48][110]: ene = nan, v_idle nan, m_idle nan
# [48][120]: ene = nan, v_idle nan, m_idle nan
# [48][130]: ene = nan, v_idle nan, m_idle nan
# [48][140]: ene = nan, v_idle nan, m_idle nan
# [48][150]: ene = nan, v_idle nan, m_idle nan
# [48][160]: ene = nan, v_idle nan, m_idle nan
# [48][170]: ene = nan, v_idle nan, m_idle nan
# [48][180]: ene = nan, v_idle nan, m_idle nan
# [48][190]: ene = nan, v_idle nan, m_idle nan
# [48][200]: ene = nan, v_idle nan, m_idle nan
# [49][10]: ene = nan, v_idle nan, m_idle nan
# [49][20]: ene = nan, v_idle nan, m_idle nan
# [49][30]: ene = nan, v_idle nan, m_idle nan
# [49][40]: ene = nan, v_idle nan, m_idle nan
# [49][50]: ene = nan, v_idle nan, m_idle nan
# [49][60]: ene = nan, v_idle nan, m_idle nan
# [49][70]: ene = nan, v_idle nan, m_idle nan
# [49][80]: ene = nan, v_idle nan, m_idle nan
# [49][90]: ene = nan, v_idle nan, m_idle nan
# [49][100]: ene = nan, v_idle nan, m_idle nan
# [49][110]: ene = nan, v_idle nan, m_idle nan
# [49][120]: ene = nan, v_idle nan, m_idle nan
# [49][130]: ene = nan, v_idle nan, m_idle nan
# [49][140]: ene = nan, v_idle nan, m_idle nan
# [49][150]: ene = nan, v_idle nan, m_idle nan
# [49][160]: ene = nan, v_idle nan, m_idle nan
# [49][170]: ene = nan, v_idle nan, m_idle nan
# [49][180]: ene = nan, v_idle nan, m_idle nan
# [49][190]: ene = nan, v_idle nan, m_idle nan
# [49][200]: ene = nan, v_idle nan, m_idle nan
# [50][10]: ene = nan, v_idle nan, m_idle nan
# [50][20]: ene = nan, v_idle nan, m_idle nan
# [50][30]: ene = nan, v_idle nan, m_idle nan
# [50][40]: ene = nan, v_idle nan, m_idle nan
# [50][50]: ene = nan, v_idle nan, m_idle nan
# [50][60]: ene = nan, v_idle nan, m_idle nan
# [50][70]: ene = nan, v_idle nan, m_idle nan
# [50][80]: ene = nan, v_idle nan, m_idle nan
# [50][90]: ene = nan, v_idle nan, m_idle nan
# [50][100]: ene = nan, v_idle nan, m_idle nan
# [50][110]: ene = nan, v_idle nan, m_idle nan
# [50][120]: ene = nan, v_idle nan, m_idle nan
# [50][130]: ene = nan, v_idle nan, m_idle nan
# [50][140]: ene = nan, v_idle nan, m_idle nan
# [50][150]: ene = nan, v_idle nan, m_idle nan
# [50][160]: ene = nan, v_idle nan, m_idle nan
# [50][170]: ene = nan, v_idle nan, m_idle nan
# [50][180]: ene = nan, v_idle nan, m_idle nan
# [50][190]: ene = nan, v_idle nan, m_idle nan
# [50][200]: ene = nan, v_idle nan, m_idle nan
# [51][10]: ene = nan, v_idle nan, m_idle nan
# [51][20]: ene = nan, v_idle nan, m_idle nan
# [51][30]: ene = nan, v_idle nan, m_idle nan
# [51][40]: ene = nan, v_idle nan, m_idle nan
# [51][50]: ene = nan, v_idle nan, m_idle nan
# [51][60]: ene = nan, v_idle nan, m_idle nan
# [51][70]: ene = nan, v_idle nan, m_idle nan
# [51][80]: ene = nan, v_idle nan, m_idle nan
# [51][90]: ene = nan, v_idle nan, m_idle nan
# [51][100]: ene = nan, v_idle nan, m_idle nan
# [51][110]: ene = nan, v_idle nan, m_idle nan
# [51][120]: ene = nan, v_idle nan, m_idle nan
# [51][130]: ene = nan, v_idle nan, m_idle nan
# [51][140]: ene = nan, v_idle nan, m_idle nan
# [51][150]: ene = nan, v_idle nan, m_idle nan
# [51][160]: ene = nan, v_idle nan, m_idle nan
# [51][170]: ene = nan, v_idle nan, m_idle nan
# [51][180]: ene = nan, v_idle nan, m_idle nan
# [51][190]: ene = nan, v_idle nan, m_idle nan
# [51][200]: ene = nan, v_idle nan, m_idle nan
# [52][10]: ene = nan, v_idle nan, m_idle nan
# [52][20]: ene = nan, v_idle nan, m_idle nan
# [52][30]: ene = nan, v_idle nan, m_idle nan
# [52][40]: ene = nan, v_idle nan, m_idle nan
# [52][50]: ene = nan, v_idle nan, m_idle nan
# [52][60]: ene = nan, v_idle nan, m_idle nan
# [52][70]: ene = nan, v_idle nan, m_idle nan
# [52][80]: ene = nan, v_idle nan, m_idle nan
# [52][90]: ene = nan, v_idle nan, m_idle nan
# [52][100]: ene = nan, v_idle nan, m_idle nan
# [52][110]: ene = nan, v_idle nan, m_idle nan
# [52][120]: ene = nan, v_idle nan, m_idle nan
# [52][130]: ene = nan, v_idle nan, m_idle nan
# [52][140]: ene = nan, v_idle nan, m_idle nan
# [52][150]: ene = nan, v_idle nan, m_idle nan
# [52][160]: ene = nan, v_idle nan, m_idle nan
# [52][170]: ene = nan, v_idle nan, m_idle nan
# [52][180]: ene = nan, v_idle nan, m_idle nan
# [52][190]: ene = nan, v_idle nan, m_idle nan
# [52][200]: ene = nan, v_idle nan, m_idle nan
# [53][10]: ene = nan, v_idle nan, m_idle nan
# [53][20]: ene = nan, v_idle nan, m_idle nan
# [53][30]: ene = nan, v_idle nan, m_idle nan
# [53][40]: ene = nan, v_idle nan, m_idle nan
# [53][50]: ene = nan, v_idle nan, m_idle nan
# [53][60]: ene = nan, v_idle nan, m_idle nan
# [53][70]: ene = nan, v_idle nan, m_idle nan
# [53][80]: ene = nan, v_idle nan, m_idle nan
# [53][90]: ene = nan, v_idle nan, m_idle nan
# [53][100]: ene = nan, v_idle nan, m_idle nan
# [53][110]: ene = nan, v_idle nan, m_idle nan
# [53][120]: ene = nan, v_idle nan, m_idle nan
# ...
# [183][100]: ene = nan, v_idle nan, m_idle nan
# [183][110]: ene = nan, v_idle nan, m_idle nan
# [183][120]: ene = nan, v_idle nan, m_idle nan
# [183][130]: ene = nan, v_idle nan, m_idle nan
# [183][140]: ene = nan, v_idle nan, m_idle nan
# [183][150]: ene = nan, v_idle nan, m_idle nan
# [183][160]: ene = nan, v_idle nan, m_idle nan
# [183][170]: ene = nan, v_idle nan, m_idle nan
# [183][180]: ene = nan, v_idle nan, m_idle nan
# [183][190]: ene = nan, v_idle nan, m_idle nan
# [183][200]: ene = nan, v_idle nan, m_idle nan
# [184][10]: ene = nan, v_idle nan, m_idle nan
# [184][20]: ene = nan, v_idle nan, m_idle nan
# [184][30]: ene = nan, v_idle nan, m_idle nan
# [184][40]: ene = nan, v_idle nan, m_idle nan
# [184][50]: ene = nan, v_idle nan, m_idle nan
# [184][60]: ene = nan, v_idle nan, m_idle nan
# [184][70]: ene = nan, v_idle nan, m_idle nan
# [184][80]: ene = nan, v_idle nan, m_idle nan
# [184][90]: ene = nan, v_idle nan, m_idle nan
# [184][100]: ene = nan, v_idle nan, m_idle nan
# [184][110]: ene = nan, v_idle nan, m_idle nan
# [184][120]: ene = nan, v_idle nan, m_idle nan
# [184][130]: ene = nan, v_idle nan, m_idle nan
# [184][140]: ene = nan, v_idle nan, m_idle nan
# [184][150]: ene = nan, v_idle nan, m_idle nan
# [184][160]: ene = nan, v_idle nan, m_idle nan
# [184][170]: ene = nan, v_idle nan, m_idle nan
# [184][180]: ene = nan, v_idle nan, m_idle nan
# [184][190]: ene = nan, v_idle nan, m_idle nan
# [184][200]: ene = nan, v_idle nan, m_idle nan
# [185][10]: ene = nan, v_idle nan, m_idle nan
# [185][20]: ene = nan, v_idle nan, m_idle nan
# [185][30]: ene = nan, v_idle nan, m_idle nan
# [185][40]: ene = nan, v_idle nan, m_idle nan
# [185][50]: ene = nan, v_idle nan, m_idle nan
# [185][60]: ene = nan, v_idle nan, m_idle nan
# [185][70]: ene = nan, v_idle nan, m_idle nan
# [185][80]: ene = nan, v_idle nan, m_idle nan
# [185][90]: ene = nan, v_idle nan, m_idle nan
# [185][100]: ene = nan, v_idle nan, m_idle nan
# [185][110]: ene = nan, v_idle nan, m_idle nan
# [185][120]: ene = nan, v_idle nan, m_idle nan
# [185][130]: ene = nan, v_idle nan, m_idle nan
# [185][140]: ene = nan, v_idle nan, m_idle nan
# [185][150]: ene = nan, v_idle nan, m_idle nan
# [185][160]: ene = nan, v_idle nan, m_idle nan
# [185][170]: ene = nan, v_idle nan, m_idle nan
# [185][180]: ene = nan, v_idle nan, m_idle nan
# [185][190]: ene = nan, v_idle nan, m_idle nan
# [185][200]: ene = nan, v_idle nan, m_idle nan
# [186][10]: ene = nan, v_idle nan, m_idle nan
# [186][20]: ene = nan, v_idle nan, m_idle nan
# [186][30]: ene = nan, v_idle nan, m_idle nan
# [186][40]: ene = nan, v_idle nan, m_idle nan
# [186][50]: ene = nan, v_idle nan, m_idle nan
# [186][60]: ene = nan, v_idle nan, m_idle nan
# [186][70]: ene = nan, v_idle nan, m_idle nan
# [186][80]: ene = nan, v_idle nan, m_idle nan
# [186][90]: ene = nan, v_idle nan, m_idle nan
# [186][100]: ene = nan, v_idle nan, m_idle nan
# [186][110]: ene = nan, v_idle nan, m_idle nan
# [186][120]: ene = nan, v_idle nan, m_idle nan
# [186][130]: ene = nan, v_idle nan, m_idle nan
# [186][140]: ene = nan, v_idle nan, m_idle nan
# [186][150]: ene = nan, v_idle nan, m_idle nan
# [186][160]: ene = nan, v_idle nan, m_idle nan
# [186][170]: ene = nan, v_idle nan, m_idle nan
# [186][180]: ene = nan, v_idle nan, m_idle nan
# [186][190]: ene = nan, v_idle nan, m_idle nan
# [186][200]: ene = nan, v_idle nan, m_idle nan
# [187][10]: ene = nan, v_idle nan, m_idle nan
# [187][20]: ene = nan, v_idle nan, m_idle nan
# [187][30]: ene = nan, v_idle nan, m_idle nan
# [187][40]: ene = nan, v_idle nan, m_idle nan
# [187][50]: ene = nan, v_idle nan, m_idle nan
# [187][60]: ene = nan, v_idle nan, m_idle nan
# [187][70]: ene = nan, v_idle nan, m_idle nan
# [187][80]: ene = nan, v_idle nan, m_idle nan
# [187][90]: ene = nan, v_idle nan, m_idle nan
# [187][100]: ene = nan, v_idle nan, m_idle nan
# [187][110]: ene = nan, v_idle nan, m_idle nan
# [187][120]: ene = nan, v_idle nan, m_idle nan
# [187][130]: ene = nan, v_idle nan, m_idle nan
# [187][140]: ene = nan, v_idle nan, m_idle nan
# [187][150]: ene = nan, v_idle nan, m_idle nan
# [187][160]: ene = nan, v_idle nan, m_idle nan
# [187][170]: ene = nan, v_idle nan, m_idle nan
# [187][180]: ene = nan, v_idle nan, m_idle nan
# [187][190]: ene = nan, v_idle nan, m_idle nan
# [187][200]: ene = nan, v_idle nan, m_idle nan
# [188][10]: ene = nan, v_idle nan, m_idle nan
# [188][20]: ene = nan, v_idle nan, m_idle nan
# [188][30]: ene = nan, v_idle nan, m_idle nan
# [188][40]: ene = nan, v_idle nan, m_idle nan
# [188][50]: ene = nan, v_idle nan, m_idle nan
# [188][60]: ene = nan, v_idle nan, m_idle nan
# [188][70]: ene = nan, v_idle nan, m_idle nan
# [188][80]: ene = nan, v_idle nan, m_idle nan
# [188][90]: ene = nan, v_idle nan, m_idle nan
# [188][100]: ene = nan, v_idle nan, m_idle nan
# [188][110]: ene = nan, v_idle nan, m_idle nan
# [188][120]: ene = nan, v_idle nan, m_idle nan
# [188][130]: ene = nan, v_idle nan, m_idle nan
# [188][140]: ene = nan, v_idle nan, m_idle nan
# [188][150]: ene = nan, v_idle nan, m_idle nan
# [188][160]: ene = nan, v_idle nan, m_idle nan
# [188][170]: ene = nan, v_idle nan, m_idle nan
# [188][180]: ene = nan, v_idle nan, m_idle nan
# [188][190]: ene = nan, v_idle nan, m_idle nan
# [188][200]: ene = nan, v_idle nan, m_idle nan
# [189][10]: ene = nan, v_idle nan, m_idle nan
# [189][20]: ene = nan, v_idle nan, m_idle nan
# [189][30]: ene = nan, v_idle nan, m_idle nan
# [189][40]: ene = nan, v_idle nan, m_idle nan
# [189][50]: ene = nan, v_idle nan, m_idle nan
# [189][60]: ene = nan, v_idle nan, m_idle nan
# [189][70]: ene = nan, v_idle nan, m_idle nan
# [189][80]: ene = nan, v_idle nan, m_idle nan
# [189][90]: ene = nan, v_idle nan, m_idle nan
# [189][100]: ene = nan, v_idle nan, m_idle nan
# [189][110]: ene = nan, v_idle nan, m_idle nan
# [189][120]: ene = nan, v_idle nan, m_idle nan
# [189][130]: ene = nan, v_idle nan, m_idle nan
# [189][140]: ene = nan, v_idle nan, m_idle nan
# [189][150]: ene = nan, v_idle nan, m_idle nan
# [189][160]: ene = nan, v_idle nan, m_idle nan
# [189][170]: ene = nan, v_idle nan, m_idle nan
# [189][180]: ene = nan, v_idle nan, m_idle nan
# [189][190]: ene = nan, v_idle nan, m_idle nan
# [189][200]: ene = nan, v_idle nan, m_idle nan
# [190][10]: ene = nan, v_idle nan, m_idle nan
# [190][20]: ene = nan, v_idle nan, m_idle nan
# [190][30]: ene = nan, v_idle nan, m_idle nan
# [190][40]: ene = nan, v_idle nan, m_idle nan
# [190][50]: ene = nan, v_idle nan, m_idle nan
# [190][60]: ene = nan, v_idle nan, m_idle nan
# [190][70]: ene = nan, v_idle nan, m_idle nan
# [190][80]: ene = nan, v_idle nan, m_idle nan
# [190][90]: ene = nan, v_idle nan, m_idle nan
# [190][100]: ene = nan, v_idle nan, m_idle nan
# [190][110]: ene = nan, v_idle nan, m_idle nan
# [190][120]: ene = nan, v_idle nan, m_idle nan
# [190][130]: ene = nan, v_idle nan, m_idle nan
# [190][140]: ene = nan, v_idle nan, m_idle nan
# [190][150]: ene = nan, v_idle nan, m_idle nan
# [190][160]: ene = nan, v_idle nan, m_idle nan
# [190][170]: ene = nan, v_idle nan, m_idle nan
# [190][180]: ene = nan, v_idle nan, m_idle nan
# [190][190]: ene = nan, v_idle nan, m_idle nan
# [190][200]: ene = nan, v_idle nan, m_idle nan
# [191][10]: ene = nan, v_idle nan, m_idle nan
# [191][20]: ene = nan, v_idle nan, m_idle nan
# [191][30]: ene = nan, v_idle nan, m_idle nan
# [191][40]: ene = nan, v_idle nan, m_idle nan
# [191][50]: ene = nan, v_idle nan, m_idle nan
# [191][60]: ene = nan, v_idle nan, m_idle nan
# [191][70]: ene = nan, v_idle nan, m_idle nan
# [191][80]: ene = nan, v_idle nan, m_idle nan
# [191][90]: ene = nan, v_idle nan, m_idle nan
# [191][100]: ene = nan, v_idle nan, m_idle nan
# [191][110]: ene = nan, v_idle nan, m_idle nan
# [191][120]: ene = nan, v_idle nan, m_idle nan
# [191][130]: ene = nan, v_idle nan, m_idle nan
# [191][140]: ene = nan, v_idle nan, m_idle nan
# [191][150]: ene = nan, v_idle nan, m_idle nan
# [191][160]: ene = nan, v_idle nan, m_idle nan
# [191][170]: ene = nan, v_idle nan, m_idle nan
# [191][180]: ene = nan, v_idle nan, m_idle nan
# [191][190]: ene = nan, v_idle nan, m_idle nan
# [191][200]: ene = nan, v_idle nan, m_idle nan
# [192][10]: ene = nan, v_idle nan, m_idle nan
# [192][20]: ene = nan, v_idle nan, m_idle nan
# [192][30]: ene = nan, v_idle nan, m_idle nan
# [192][40]: ene = nan, v_idle nan, m_idle nan
# [192][50]: ene = nan, v_idle nan, m_idle nan
# [192][60]: ene = nan, v_idle nan, m_idle nan
# [192][70]: ene = nan, v_idle nan, m_idle nan
# [192][80]: ene = nan, v_idle nan, m_idle nan
# [192][90]: ene = nan, v_idle nan, m_idle nan
# [192][100]: ene = nan, v_idle nan, m_idle nan
# [192][110]: ene = nan, v_idle nan, m_idle nan
# [192][120]: ene = nan, v_idle nan, m_idle nan
# [192][130]: ene = nan, v_idle nan, m_idle nan
# [192][140]: ene = nan, v_idle nan, m_idle nan
# [192][150]: ene = nan, v_idle nan, m_idle nan
# [192][160]: ene = nan, v_idle nan, m_idle nan
# [192][170]: ene = nan, v_idle nan, m_idle nan
# [192][180]: ene = nan, v_idle nan, m_idle nan
# [192][190]: ene = nan, v_idle nan, m_idle nan
# [192][200]: ene = nan, v_idle nan, m_idle nan
# [193][10]: ene = nan, v_idle nan, m_idle nan
# [193][20]: ene = nan, v_idle nan, m_idle nan
# [193][30]: ene = nan, v_idle nan, m_idle nan
# [193][40]: ene = nan, v_idle nan, m_idle nan
# [193][50]: ene = nan, v_idle nan, m_idle nan
# [193][60]: ene = nan, v_idle nan, m_idle nan
# [193][70]: ene = nan, v_idle nan, m_idle nan
# [193][80]: ene = nan, v_idle nan, m_idle nan
# [193][90]: ene = nan, v_idle nan, m_idle nan
# [193][100]: ene = nan, v_idle nan, m_idle nan
# [193][110]: ene = nan, v_idle nan, m_idle nan
# [193][120]: ene = nan, v_idle nan, m_idle nan
# [193][130]: ene = nan, v_idle nan, m_idle nan
# [193][140]: ene = nan, v_idle nan, m_idle nan
# [193][150]: ene = nan, v_idle nan, m_idle nan
# [193][160]: ene = nan, v_idle nan, m_idle nan
# [193][170]: ene = nan, v_idle nan, m_idle nan
# [193][180]: ene = nan, v_idle nan, m_idle nan
# [193][190]: ene = nan, v_idle nan, m_idle nan
# [193][200]: ene = nan, v_idle nan, m_idle nan
# [194][10]: ene = nan, v_idle nan, m_idle nan
# [194][20]: ene = nan, v_idle nan, m_idle nan
# [194][30]: ene = nan, v_idle nan, m_idle nan
# [194][40]: ene = nan, v_idle nan, m_idle nan
# [194][50]: ene = nan, v_idle nan, m_idle nan
# [194][60]: ene = nan, v_idle nan, m_idle nan
# [194][70]: ene = nan, v_idle nan, m_idle nan
# [194][80]: ene = nan, v_idle nan, m_idle nan
# [194][90]: ene = nan, v_idle nan, m_idle nan
# [194][100]: ene = nan, v_idle nan, m_idle nan
# [194][110]: ene = nan, v_idle nan, m_idle nan
# [194][120]: ene = nan, v_idle nan, m_idle nan
# [194][130]: ene = nan, v_idle nan, m_idle nan
# [194][140]: ene = nan, v_idle nan, m_idle nan
# [194][150]: ene = nan, v_idle nan, m_idle nan
# [194][160]: ene = nan, v_idle nan, m_idle nan
# [194][170]: ene = nan, v_idle nan, m_idle nan
# [194][180]: ene = nan, v_idle nan, m_idle nan
# [194][190]: ene = nan, v_idle nan, m_idle nan
# [194][200]: ene = nan, v_idle nan, m_idle nan
# [195][10]: ene = nan, v_idle nan, m_idle nan
# [195][20]: ene = nan, v_idle nan, m_idle nan
# [195][30]: ene = nan, v_idle nan, m_idle nan
# [195][40]: ene = nan, v_idle nan, m_idle nan
# [195][50]: ene = nan, v_idle nan, m_idle nan
# [195][60]: ene = nan, v_idle nan, m_idle nan
# [195][70]: ene = nan, v_idle nan, m_idle nan
# [195][80]: ene = nan, v_idle nan, m_idle nan
# [195][90]: ene = nan, v_idle nan, m_idle nan
# [195][100]: ene = nan, v_idle nan, m_idle nan
# [195][110]: ene = nan, v_idle nan, m_idle nan
# [195][120]: ene = nan, v_idle nan, m_idle nan
# [195][130]: ene = nan, v_idle nan, m_idle nan
# [195][140]: ene = nan, v_idle nan, m_idle nan
# [195][150]: ene = nan, v_idle nan, m_idle nan
# [195][160]: ene = nan, v_idle nan, m_idle nan
# [195][170]: ene = nan, v_idle nan, m_idle nan
# [195][180]: ene = nan, v_idle nan, m_idle nan
# [195][190]: ene = nan, v_idle nan, m_idle nan
# [195][200]: ene = nan, v_idle nan, m_idle nan
# [196][10]: ene = nan, v_idle nan, m_idle nan
# [196][20]: ene = nan, v_idle nan, m_idle nan
# [196][30]: ene = nan, v_idle nan, m_idle nan
# [196][40]: ene = nan, v_idle nan, m_idle nan
# [196][50]: ene = nan, v_idle nan, m_idle nan
# [196][60]: ene = nan, v_idle nan, m_idle nan
# [196][70]: ene = nan, v_idle nan, m_idle nan
# [196][80]: ene = nan, v_idle nan, m_idle nan
# [196][90]: ene = nan, v_idle nan, m_idle nan
# [196][100]: ene = nan, v_idle nan, m_idle nan
# [196][110]: ene = nan, v_idle nan, m_idle nan
# [196][120]: ene = nan, v_idle nan, m_idle nan
# [196][130]: ene = nan, v_idle nan, m_idle nan
# [196][140]: ene = nan, v_idle nan, m_idle nan
# [196][150]: ene = nan, v_idle nan, m_idle nan
# [196][160]: ene = nan, v_idle nan, m_idle nan
# [196][170]: ene = nan, v_idle nan, m_idle nan
# [196][180]: ene = nan, v_idle nan, m_idle nan
# [196][190]: ene = nan, v_idle nan, m_idle nan
# [196][200]: ene = nan, v_idle nan, m_idle nan
# [197][10]: ene = nan, v_idle nan, m_idle nan
# [197][20]: ene = nan, v_idle nan, m_idle nan
# [197][30]: ene = nan, v_idle nan, m_idle nan
# [197][40]: ene = nan, v_idle nan, m_idle nan
# [197][50]: ene = nan, v_idle nan, m_idle nan
# [197][60]: ene = nan, v_idle nan, m_idle nan
# [197][70]: ene = nan, v_idle nan, m_idle nan
# [197][80]: ene = nan, v_idle nan, m_idle nan
# [197][90]: ene = nan, v_idle nan, m_idle nan
# [197][100]: ene = nan, v_idle nan, m_idle nan
# [197][110]: ene = nan, v_idle nan, m_idle nan
# [197][120]: ene = nan, v_idle nan, m_idle nan
# [197][130]: ene = nan, v_idle nan, m_idle nan
# [197][140]: ene = nan, v_idle nan, m_idle nan
# [197][150]: ene = nan, v_idle nan, m_idle nan
# [197][160]: ene = nan, v_idle nan, m_idle nan
# [197][170]: ene = nan, v_idle nan, m_idle nan
# [197][180]: ene = nan, v_idle nan, m_idle nan
# [197][190]: ene = nan, v_idle nan, m_idle nan
# [197][200]: ene = nan, v_idle nan, m_idle nan
# [198][10]: ene = nan, v_idle nan, m_idle nan
# [198][20]: ene = nan, v_idle nan, m_idle nan
# [198][30]: ene = nan, v_idle nan, m_idle nan
# [198][40]: ene = nan, v_idle nan, m_idle nan
# [198][50]: ene = nan, v_idle nan, m_idle nan
# [198][60]: ene = nan, v_idle nan, m_idle nan
# [198][70]: ene = nan, v_idle nan, m_idle nan
# [198][80]: ene = nan, v_idle nan, m_idle nan
# [198][90]: ene = nan, v_idle nan, m_idle nan
# [198][100]: ene = nan, v_idle nan, m_idle nan
# [198][110]: ene = nan, v_idle nan, m_idle nan
# [198][120]: ene = nan, v_idle nan, m_idle nan
# [198][130]: ene = nan, v_idle nan, m_idle nan
# [198][140]: ene = nan, v_idle nan, m_idle nan
# [198][150]: ene = nan, v_idle nan, m_idle nan
# [198][160]: ene = nan, v_idle nan, m_idle nan
# [198][170]: ene = nan, v_idle nan, m_idle nan
# [198][180]: ene = nan, v_idle nan, m_idle nan
# [198][190]: ene = nan, v_idle nan, m_idle nan
# [198][200]: ene = nan, v_idle nan, m_idle nan
# [199][10]: ene = nan, v_idle nan, m_idle nan
# [199][20]: ene = nan, v_idle nan, m_idle nan
# [199][30]: ene = nan, v_idle nan, m_idle nan
# [199][40]: ene = nan, v_idle nan, m_idle nan
# [199][50]: ene = nan, v_idle nan, m_idle nan
# [199][60]: ene = nan, v_idle nan, m_idle nan
# [199][70]: ene = nan, v_idle nan, m_idle nan
# [199][80]: ene = nan, v_idle nan, m_idle nan
# [199][90]: ene = nan, v_idle nan, m_idle nan
# [199][100]: ene = nan, v_idle nan, m_idle nan
# [199][110]: ene = nan, v_idle nan, m_idle nan
# [199][120]: ene = nan, v_idle nan, m_idle nan
# [199][130]: ene = nan, v_idle nan, m_idle nan
# [199][140]: ene = nan, v_idle nan, m_idle nan
# [199][150]: ene = nan, v_idle nan, m_idle nan
# [199][160]: ene = nan, v_idle nan, m_idle nan
# [199][170]: ene = nan, v_idle nan, m_idle nan
# [199][180]: ene = nan, v_idle nan, m_idle nan
# [199][190]: ene = nan, v_idle nan, m_idle nan
# [199][200]: ene = nan, v_idle nan, m_idle nan
# [200][10]: ene = nan, v_idle nan, m_idle nan
# [200][20]: ene = nan, v_idle nan, m_idle nan
# [200][30]: ene = nan, v_idle nan, m_idle nan
# [200][40]: ene = nan, v_idle nan, m_idle nan
# [200][50]: ene = nan, v_idle nan, m_idle nan
# [200][60]: ene = nan, v_idle nan, m_idle nan
# [200][70]: ene = nan, v_idle nan, m_idle nan
# [200][80]: ene = nan, v_idle nan, m_idle nan
# [200][90]: ene = nan, v_idle nan, m_idle nan
# [200][100]: ene = nan, v_idle nan, m_idle nan
# [200][110]: ene = nan, v_idle nan, m_idle nan
# [200][120]: ene = nan, v_idle nan, m_idle nan
# [200][130]: ene = nan, v_idle nan, m_idle nan
# [200][140]: ene = nan, v_idle nan, m_idle nan
# [200][150]: ene = nan, v_idle nan, m_idle nan
# [200][160]: ene = nan, v_idle nan, m_idle nan
# [200][170]: ene = nan, v_idle nan, m_idle nan
# [200][180]: ene = nan, v_idle nan, m_idle nan
# [200][190]: ene = nan, v_idle nan, m_idle nan
# [200][200]: ene = nan, v_idle nan, m_idle nan

# %%
plt.plot(ene_list)

# %% [markdown]
# # 6. 可视化

# %%
# hello!
print("say hi!")
# github shabi
# Out:
# say hi!

# %% [markdown]
# # 其他

# %%
def status(e:Edge):
    return e.v1.info._status + e.v2.info._status

# %%
status_list = [status(e) for e in FASTnet.edge_list]
plot(status_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_347/1466560726.py in <module>
#       1 status_list = [status(e) for e in FASTnet.edge_list]
# ----> 2 plot(status_list)
#
# NameError: name 'plot' is not defined
